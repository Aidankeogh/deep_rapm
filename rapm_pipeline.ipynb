# %% [markdown]
# # Data Pipeline for Calculating RAPM
#
# To run the following code, you will need this software:
#
# ## Software Prequisites
#
#
# Option 1 (Running with Docker):
# - [Docker](https://www.docker.com/) and docker-compose
#
# Option 2 (Running locally):
# - [Anaconda](https://anaconda.org/anaconda/python)
# - [MongoDB](https://www.mongodb.com/)
#
# Option 3 (Mixed):
# - You can also run Anaconda locally and Mongo out of a docker container or vice versa
#
# Once you have the above installed, you can proceed with these steps:
#
# ## Table of Contents
#
# - Scrape Data
# - Import Data into Database
# - Process Play-by-Play Data
# - Convert Play-by-Play/Possession Data into Matrix
# - Run Regression Model with Matrix
#
# ## 1. Scrape Data
#
# We use scripts to scrape the following for a given season:
# - List of Game IDs and associated information (from nba.com)
# - Play-By-Play Data for each game (from nba.com)
#
# The following are also scraped for comparison against other advanced stats
# - Player Advanced Stats (from basketball-reference.com)
# - Team Advanced Stats (from basketball-reference.com)
# - RPM data (from espn.com)
#
# The ```collect_all_season_data()``` function will finish by creating a .tar.gz file with all the above contents.

# %%
import os
os.chdir("data_collector")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-8459641e6e18> in <module>()
#       1 import os
# ----> 2 os.chdir("data_collector")
#
# OSError: [Errno 2] No such file or directory: 'data_collector'

# %%
# move into the data_collector directory
import collect_nba_data
year = 2015
collect_nba_data.collect_all_season_data(year)
# Out:
# Found /home/aidan/rapm-model/data_collector/2014-15/games_preseason_2015.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400001.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400002.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400003.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400004.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400005.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400006.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400007.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400008.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400009.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400010.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400011.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400012.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400013.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400014.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400015.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400016.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400017.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400018.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400019.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400020.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400021.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400022.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400023.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400024.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400025.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400026.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400027.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400028.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400029.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400030.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400031.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400032.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400033.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400034.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400035.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400036.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400037.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400038.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400039.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400040.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400041.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400042.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400043.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400044.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400045.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400046.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400047.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400048.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400049.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400050.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400051.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400052.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400053.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400054.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400055.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400056.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400057.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400058.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400059.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400060.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400061.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400062.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400063.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400064.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400065.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400066.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400067.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400068.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400069.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400070.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400071.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400072.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400073.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400074.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400075.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400076.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400077.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400078.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400079.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400080.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400081.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400082.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400083.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400084.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400085.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400086.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400087.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400088.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400089.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400090.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400091.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400092.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400093.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400094.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400095.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400096.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400097.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400098.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400099.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400100.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400101.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400102.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400103.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400104.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400105.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400106.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400107.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400108.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400109.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400110.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400111.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400112.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400113.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400114.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400115.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400116.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400117.json
# Found /home/aidan/rapm-model/data_collector/2014-15/preseason/0011400118.json
# Found /home/aidan/rapm-model/data_collector/2014-15/games_playoffs_2015.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400101.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400102.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400103.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400104.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400105.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400106.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400111.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400112.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400113.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400114.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400121.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400122.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400123.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400124.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400125.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400126.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400131.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400132.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400133.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400134.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400141.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400142.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400143.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400144.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400151.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400152.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400153.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400154.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400155.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400161.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400162.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400163.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400164.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400165.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400166.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400167.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400171.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400172.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400173.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400174.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400175.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400201.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400202.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400203.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400204.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400205.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400206.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400211.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400212.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400213.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400214.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400215.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400216.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400221.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400222.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400223.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400224.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400225.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400226.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400231.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400232.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400233.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400234.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400235.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400236.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400237.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400301.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400302.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400303.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400304.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400311.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400312.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400313.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400314.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400315.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400401.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400402.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400403.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400404.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400405.json
# Found /home/aidan/rapm-model/data_collector/2014-15/playoffs/0041400406.json
# Found /home/aidan/rapm-model/data_collector/2014-15/games_regular_season_2015.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400001.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400002.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400003.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400004.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400005.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400006.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400007.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400008.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400009.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400010.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400011.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400012.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400013.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400014.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400015.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400016.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400017.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400018.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400019.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400020.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400021.json
# Found /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021
json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400569.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400570.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400571.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400572.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400573.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400574.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400575.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400576.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400577.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400578.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400579.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400580.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400581.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400582.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400583.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400584.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400585.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400586.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400587.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400588.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400589.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400590.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400591.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400592.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400593.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400594.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400595.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400596.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400597.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400598.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400599.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400600.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400601.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400602.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400603.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400604.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400605.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400606.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400607.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400608.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400609.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400610.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400611.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400612.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400613.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400614.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400615.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400616.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400617.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400618.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400619.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400620.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400621.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400622.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400623.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400624.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400625.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400626.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400627.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400628.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400629.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400630.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400631.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400632.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400633.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400634.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400635.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400636.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400637.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400638.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400639.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400640.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400641.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400642.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400643.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400644.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400645.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400646.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400647.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400648.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400649.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400650.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400651.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400652.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400653.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400654.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400655.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400656.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400657.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400658.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400659.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400660.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400661.json
# Write /home/aidan/rapm-model/data_collector/2014-15/regular_season/0021400662.json
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-7-6f54332a0c59> in <module>()
#       3 import collect_nba_data
#       4 year = 2015
# ----> 5 collect_nba_data.collect_all_season_data(year)
#
# /home/aidan/rapm-model/data_collector/collect_nba_data.pyc in collect_all_season_data(year)
#     192             file_path = os.path.join(subseason_data_path, game_id) + ".json"
#     193             if not os.path.exists(file_path):
# --> 194                 pbp_json = fetch_pbp(game_id)
#     195                 with open(file_path,"w") as json_file:
#     196                     print("Write {}".format(file_path))
#
# /home/aidan/rapm-model/data_collector/collect_nba_data.pyc in fetch_pbp(game_id)
#      62 def fetch_pbp(game_id):
#      63     url = construct_pbp_url(game_id)
# ---> 64     r = requests.get(url, headers=headers)
#      65     data = r.json()
#      66     pbp = data['resultSets'][0]['rowSet']
#
# /home/aidan/anaconda2/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /home/aidan/anaconda2/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /home/aidan/anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /home/aidan/anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# /home/aidan/anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     216                     proxies=proxies,
#     217                     allow_redirects=False,
# --> 218                     **adapter_kwargs
#     219                 )
#     220
#
# /home/aidan/anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /home/aidan/anaconda2/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     488
#     489         except (ProtocolError, socket.error) as err:
# --> 490             raise ConnectionError(err, request=request)
#     491
#     492         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', error("(104, 'ECONNRESET')",))

# %% [markdown]
# ## 2. Import the Data into a Database
#
# This project uses a MongoDB database to store scraped and processed data. The preferred way to start a MongoDB instance with this project is using [Docker](https://docs.docker.com/install/).
#
# 1. [Install Docker]([Docker](https://docs.docker.com/install/)
# 2. From the command line in the rapm-model directory:
#
#    ```docker-compose up```
#
# 3. The above command will start an instance of MongoDB running at localhost:27017 with no password by default. You can use a GUI tool like MongoDB Compass or Robo 3T to view the contents of the database.

# %%
import importlib
import data_importer
#importlib.reload(data_importer)

year = 2018
# if we delete the original files but still have the archive file we unzip it first
# data_importer.unarchive_data(year)

# Creates a games.[season] collection and each row of the table is a game object
# with following keys: {"game_index", "pbp"}
data_importer.import_games_pbp_into_mongo(year, "playoffs")

# Does some extra processing to update the rows in the games.[season] table 
# with the following keys: {"away", "home", "date"}
data_importer.import_game_info_into_mongo(year, "playoffs")

# Reads the scraped basketball-reference players table and imports it into
# the "players" collection in Mongo. 
data_importer.import_players_into_mongo(year)

# Reads the scraped basketball-reference teams table and imports it into
# the "teams" collection in Mongo. 
data_importer.import_teams_into_mongo(year)

# Reads the scraped RPM data and adds it to the previously created players table for each player
data_importer.add_rpm_to_player_table(year)

# %% [markdown]
# ## 3. Process Play-by-Play Data
#
# Here we convert the raw play-by-play data from nba.com to a version with lineup infomation, which we need to do the RAPM calculation. More precisely, we parse the play-by-play data into this form:
#
# ```json
# [ {
#     "home_lineup": [playerid1, ..., playerid5],
#     "away_lineup": [playerid6, ..., playerid10],
#     "score_margin_update": 2, #(0-4 range of points that can be scored on a possession, not accounting for weirdness that can happen with technicals, flagrants)
#     "home_team_is_on_offense": True, # or false,
#     "possession_metadata": 3 #any data we want to keep about what the event was, at least event number for reference
#    }, {...}, ...
# ]
# ```
# Each object in the list is denotes a possession ending, either a turnover, made shot, defensive rebound, or the last of a series of free throws.
#
# We store this in a collection called possessions.[season] for each season

# %%
# get back into main rapm-model directory
# only run this once, or just put in an absolute path e.g. /home/dev/rapm-model
os.chdir("..")

# %%
import parse_pbp
import importlib
import common_utils
importlib.reload(parse_pbp)
importlib.reload(common_utils)

year = 2018
parse_pbp.save_lineup_data_for_season(year, "playoffs")

# %% [markdown]
# ## 4. Convert Play-by-Play/Possession Data into Matrix
#
# We convert the possessions to matrix as described in [this talk by Jeremias Engelmann](https://www.youtube.com/watch?v=OuC0YZTADcE) and summarized in the accompanying paper. These matrices were too big for the MongoDB database and are stored as python pickles.

# %%
import calculate_rapm
import importlib

importlib.reload(calculate_rapm)

# Creates a seasons table in MongoDB where each row is an NBA season with the following attributes:
# {"year_string", "games_data"}
# "games_data" is an object where the keys are the game_ids and the information stored is the home and away team for that game
#     This is totally redundant with the games collection, but stored in a way for faster lookups
calculate_rapm.store_games_data(year, "playoffs")

# This does a pass through the possessions collection and calculates possession count for each player
# It updates the "seasons" collection with an additional "player_info" attribute
# which is an object where the keys are the player name and team and the data associated with it a numerical index, a possession count, and a player stub name
# It also updates the players table with the possession counts
calculate_rapm.store_player_and_possession_data_for_matrix(year, "playoffs")

# This does a pass through the possessions data and creates the player/possession matrix for calculating RAPM
X, Y = calculate_rapm.build_matrix(year, "playoffs")

# %% [markdown]
# ## 5. Run Regression Model w/ Matrix

# %%
import pickle

import calculate_rapm
from common_utils import construct_year_string
year = 2018
year_string = construct_year_string(year)
X = pickle.load(open("matrices/{}-X-playoffs.indicator.pickle".format(year_string), "rb"))
Y = pickle.load(open("matrices/{}-Y-playoffs.pickle".format(year_string), "rb"))
# The above steps should only need to be done once so long as no new games are added
# This step runs the model, stores the values to the players table and prints out the top 50 in ORAPM
calculate_rapm.calculate_rapm(year, X, Y, season_type="playoffs")

# RAPMs are calculated for each "player-team" pair
# For traded players, this calculates a weighted average for their whole season
calculate_rapm.deal_with_traded_players(year)

# %%
import json

from pymongo import MongoClient

import mongo_config

client = MongoClient(mongo_config.host, mongo_config.port)
db = client.nba

players = db.players.find(
    filter = {
        "player_index.season": 2018
    },
    projection= {
        "player": 1,
        "team_id": 1,
        "orapm_playoffs": 1,
        "drapm_playoffs": 1,
        "rapm_playoffs": 1,
        "playoffs_possessions": 1
    }, 
    sort= [("rapm_playoffs", -1)]
)
result = []
index = 1
for player in players:
    if "playoffs_possessions" in player:
        result.append([
            index,
            player["player"],
            player["team_id"],
            player["playoffs_possessions"],
            round(player["orapm_playoffs"], 4),
            round(player["drapm_playoffs"], 4),
            round(player["rapm_playoffs"], 4)
        ])
        index += 1
#print(result)
with open("2017-18-playoffs-rapm.json", "w") as jsonfile:
    json.dump({
        "data": result
    }, jsonfile)
