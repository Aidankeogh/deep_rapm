# %% [markdown]
# # Data Pipeline for Calculating RAPM
#
# To run the following code, you will need this software:
#
# ## Software Prequisites
#
#
# Option 1 (Running with Docker):
# - [Docker](https://www.docker.com/) and docker-compose
#
# Option 2 (Running locally):
# - [Anaconda](https://anaconda.org/anaconda/python)
# - [MongoDB](https://www.mongodb.com/)
#
# Option 3 (Mixed):
# - You can also run Anaconda locally and Mongo out of a docker container or vice versa
#
# Once you have the above installed, you can proceed with these steps:
#
# ## Table of Contents
#
# - Scrape Data
# - Import Data into Database
# - Process Play-by-Play Data
# - Convert Play-by-Play/Possession Data into Matrix
# - Run Regression Model with Matrix
#
# ## 1. Scrape Data
#
# We use scripts to scrape the following for a given season:
# - List of Game IDs and associated information (from nba.com)
# - Play-By-Play Data for each game (from nba.com)
#
# The following are also scraped for comparison against other advanced stats
# - Player Advanced Stats (from basketball-reference.com)
# - Team Advanced Stats (from basketball-reference.com)
# - RPM data (from espn.com)
#
# The ```collect_all_season_data()``` function will finish by creating a .tar.gz file with all the above contents.

# %%
import os
os.chdir("data_collector")

# %%
# move into the data_collector directory
import collect_nba_data
year = 1996

while(1):
    try:
        collect_nba_data.collect_all_season_data(year)
        year = year - 1
    except:
        pass
# Out:
# Found /home/aidan/rapm-model/data_collector/1995-96/games_preseason_1996.json
# Found /home/aidan/rapm-model/data_collector/1995-96/games_playoffs_1996.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500001.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500002.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500003.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500004.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500005.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500006.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500007.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500008.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500009.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500010.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500011.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500012.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500013.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500014.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500015.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500016.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500017.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500018.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500019.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500020.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500021.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500022.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500023.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500024.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500025.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500026.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500027.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500028.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500029.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500030.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500031.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500032.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500033.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500034.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500035.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500036.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500037.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500038.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500039.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500040.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500041.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500042.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500043.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500044.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500045.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500046.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500047.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500048.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500049.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500050.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500051.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500052.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500053.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500054.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500055.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500056.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500057.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500058.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500059.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500060.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500061.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500062.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500063.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500064.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500065.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500066.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500067.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500068.json
# Found /home/aidan/rapm-model/data_collector/1995-96/games_regular_season_1996.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500001.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500002.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500003.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500004.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500005.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500006.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500007.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500008.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500009.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500010.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500011.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500012.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500013.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500014.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500015.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500016.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500017.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500018.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500019.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500020.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500021.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500022.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500023.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500024.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500025.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500026.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500027.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500028.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500029.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500030.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500031.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500032.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500033.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500034.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500035.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500036.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500037.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500038.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500039.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500040.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500041.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500042.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500043.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500044.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500045.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500046.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500047.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500048.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500049.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500050.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500051.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500052.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500053.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500054.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500055.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500056.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500057.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500058.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500059.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500060.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500061.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500062.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500063.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500064.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500065.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500066.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500067.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500068.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500069.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500070.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500071.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500072.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500073.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500074.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500075.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500076.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500077.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500078.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500079.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500080.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500081.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500082.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500083.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500084.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500085.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500086.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500087.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500088.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500089.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500090.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500091.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500092.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500093.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500094.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500095.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500096.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500097.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500098.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500099.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500100.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500101.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500102.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500103.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500104.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500105.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500106.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500107.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500108.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500109.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500110.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500111.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500112.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500113.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500114.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500115.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500116.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500117.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500118.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500119.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500120.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500121.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500122.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500123.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500124.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500125.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500126.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500127.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500128.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500129.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500130.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500131.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500132.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500133.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500134.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500135.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500136.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500137.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500138.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500139.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500140.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500141.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500142.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500143.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500144.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500145.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500146.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500147.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500148.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500149.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500150.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500151.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500152.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500153.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500154.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500155.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500156.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500157.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500158.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500159.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500160.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500161.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500162.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500163.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500164.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500165.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500166.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500167.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500168.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500169.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500170.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500171.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500172.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500173.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500174.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500175.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500176.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500177.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500178.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500179.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500180.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500181.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500182.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500183.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500184.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500185.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500186.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500187.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500188.json
# Found /home/aidan/rapm-model/data_collector/1995-96/games_preseason_1996.json
# Found /home/aidan/rapm-model/data_collector/1995-96/games_playoffs_1996.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500001.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500002.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500003.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500004.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500005.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500006.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500007.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500008.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500009.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500010.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500011.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500012.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500013.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500014.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500015.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500016.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500017.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500018.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500019.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500020.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500021.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500022.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500023.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500024.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500025.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500026.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500027.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500028.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500029.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500030.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500031.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500032.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500033.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500034.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500035.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500036.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500037.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500038.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500039.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500040.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500041.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500042.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500043.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500044.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500045.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500046.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500047.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500048.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500049.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500050.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500051.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500052.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500053.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500054.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500055.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500056.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500057.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500058.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500059.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500060.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500061.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500062.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500063.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500064.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500065.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500066.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500067.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500068.json
# Found /home/aidan/rapm-model/data_collector/1995-96/games_regular_season_1996.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500001.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500002.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500003.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500004.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500005.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500006.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500007.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500008.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500009.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500010.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500011.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500012.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500013.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500014.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500015.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500016.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500017.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500018.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500019.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500020.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500021.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500022.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500023.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500024.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500025.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500026.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500027.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500028.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500029.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500030.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500031.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500032.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500033.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500034.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500035.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500036.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500037.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500038.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500039.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500040.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500041.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500042.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500043.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500044.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500045.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500046.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500047.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500048.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500049.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500050.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500051.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500052.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500053.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500054.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500055.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500056.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500057.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500058.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500059.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500060.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500061.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500062.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500063.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500064.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500065.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500066.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500067.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500068.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500069.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500070.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500071.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500072.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500073.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500074.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500075.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500076.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500077.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500078.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500079.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500080.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500081.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500082.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500083.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500084.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500085.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500086.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500087.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500088.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500089.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500090.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500091.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500092.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500093.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500094.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500095.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500096.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500097.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500098.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500099.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500100.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500101.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500102.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500103.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500104.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500105.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500106.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500107.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500108.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500109.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500110.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500111.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500112.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500113.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500114.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500115.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500116.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500117.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500118.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500119.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500120.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500121.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500122.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500123.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500124.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500125.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500126.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500127.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500128.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500129.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500130.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500131.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500132.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500133.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500134.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500135.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500136.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500137.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500138.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500139.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500140.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500141.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500142.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500143.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500144.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500145.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500146.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500147.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500148.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500149.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500150.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500151.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500152.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500153.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500154.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500155.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500156.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500157.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500158.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500159.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500160.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500161.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500162.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500163.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500164.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500165.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500166.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500167.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500168.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500169.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500170.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500171.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500172.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500173.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500174.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500175.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500176.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500177.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500178.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500179.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500180.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500181.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500182.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500183.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500184.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500185.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500186.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500187.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500188.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500189.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500190.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500191.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500192.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500193.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500194.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500195.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500196.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500197.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500198.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500199.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500200.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500201.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500202.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500203.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500204.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500205.json
# Found /home/aidan/rapm-model/data_collector/1995-96/games_preseason_1996.json
# Found /home/aidan/rapm-model/data_collector/1995-96/games_playoffs_1996.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500001.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500002.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500003.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500004.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500005.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500006.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500007.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500008.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500009.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500010.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500011.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500012.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500013.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500014.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500015.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500016.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500017.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500018.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500019.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500020.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500021.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500022.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500023.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500024.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500025.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500026.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500027.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500028.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500029.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500030.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500031.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500032.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500033.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500034.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500035.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500036.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500037.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500038.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500039.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500040.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500041.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500042.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500043.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500044.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500045.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500046.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500047.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500048.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500049.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500050.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500051.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500052.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500053.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500054.json
# Found /home/aidan/rapm-model/data_collector/1995-96/playoffs/0049500055.json
# ...
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500122.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500123.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500124.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500125.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500126.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500127.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500128.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500129.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500130.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500131.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500132.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500133.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500134.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500135.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500136.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500137.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500138.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500139.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500140.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500141.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500142.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500143.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500144.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500145.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500146.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500147.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500148.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500149.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500150.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500151.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500152.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500153.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500154.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500155.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500156.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500157.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500158.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500159.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500160.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500161.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500162.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500163.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500164.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500165.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500166.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500167.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500168.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500169.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500170.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500171.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500172.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500173.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500174.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500175.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500176.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500177.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500178.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500179.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500180.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500181.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500182.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500183.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500184.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500185.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500186.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500187.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500188.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500189.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500190.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500191.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500192.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500193.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500194.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500195.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500196.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500197.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500198.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500199.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500200.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500201.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500202.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500203.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500204.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500205.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500206.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500207.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500208.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500209.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500210.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500211.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500212.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500213.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500214.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500215.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500216.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500217.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500218.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500219.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500220.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500221.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500222.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500223.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500224.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500225.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500226.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500227.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500228.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500229.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500230.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500231.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500232.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500233.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500234.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500235.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500236.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500237.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500238.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500239.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500240.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500241.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500242.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500243.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500244.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500245.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500246.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500247.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500248.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500249.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500250.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500251.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500252.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500253.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500254.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500255.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500256.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500257.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500258.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500259.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500260.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500261.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500262.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500263.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500264.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500265.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500266.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500267.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500268.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500269.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500270.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500271.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500272.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500273.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500274.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500275.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500276.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500277.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500278.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500279.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500280.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500281.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500282.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500283.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500284.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500285.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500286.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500287.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500288.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500289.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500290.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500291.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500292.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500293.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500294.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500295.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500296.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500297.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500298.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500299.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500300.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500301.json
# Found /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500302.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500303.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500304.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500305.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500306.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500307.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500308.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500309.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500310.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500311.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500312.json
# Write /home/aidan/rapm-model/data_collector/1995-96/regular_season/0029500313.json

# %% [markdown]
# ## 2. Import the Data into a Database
#
# This project uses a MongoDB database to store scraped and processed data. The preferred way to start a MongoDB instance with this project is using [Docker](https://docs.docker.com/install/).
#
# 1. [Install Docker]([Docker](https://docs.docker.com/install/)
# 2. From the command line in the rapm-model directory:
#
#    ```docker-compose up```
#
# 3. The above command will start an instance of MongoDB running at localhost:27017 with no password by default. You can use a GUI tool like MongoDB Compass or Robo 3T to view the contents of the database.

# %%
import importlib
import data_importer
#importlib.reload(data_importer)

year = 2018
# if we delete the original files but still have the archive file we unzip it first
# data_importer.unarchive_data(year)

# Creates a games.[season] collection and each row of the table is a game object
# with following keys: {"game_index", "pbp"}
data_importer.import_games_pbp_into_mongo(year, "playoffs")

# Does some extra processing to update the rows in the games.[season] table 
# with the following keys: {"away", "home", "date"}
data_importer.import_game_info_into_mongo(year, "playoffs")

# Reads the scraped basketball-reference players table and imports it into
# the "players" collection in Mongo. 
data_importer.import_players_into_mongo(year)

# Reads the scraped basketball-reference teams table and imports it into
# the "teams" collection in Mongo. 
data_importer.import_teams_into_mongo(year)

# Reads the scraped RPM data and adds it to the previously created players table for each player
data_importer.add_rpm_to_player_table(year)
# Out:
# creating database index
# database index created (or already existed)
# Importing game_ids... (only showing every 100)
# Inserted game_id 0041700101
# creating index
# {u'_id_': {u'key': [(u'_id', 1)], u'ns': u'nba.players', u'v': 2},
#  u'player_index.name_stub_1_player_index.season_1_player_index.team_1': {u'key': [(u'player_index.name_stub',
#                                                                                    1),
#                                                                                   (u'player_index.season',
#                                                                                    1),
#                                                                                   (u'player_index.team',
#                                                                                    1)],
#                                                                          u'ns': u'nba.players',
#                                                                          u'unique': True,
#                                                                          u'v': 2}}
# index created (or already existed)
# import alexabrines_OKC_2018
# import quincyacy_BRK_2018
# import stevenadams_OKC_2018
# import bamadebayo_MIA_2018
# import arronafflalo_ORL_2018
# import colealdrich_MIN_2018
# import lamarcusaldridge_SAS_2018
# import jarrettallen_BRK_2018
# import kadeemallen_BOS_2018
# import tonyallen_NOP_2018
# import alfarouqaminu_POR_2018
# import justinanderson_PHI_2018
# import kyleanderson_SAS_2018
# import ryananderson_HOU_2018
# import ikeanigbogu_IND_2018
# import giannisantetokounmpo_MIL_2018
# import carmeloanthony_OKC_2018
# import oganunoby_TOR_2018
# import ryanarcidiacono_CHI_2018
# import trevorariza_HOU_2018
# import darrellarthur_DEN_2018
# import jamelartis_ORL_2018
# import omerasik_TOT_2018
# import omerasik_NOP_2018
# import omerasik_CHI_2018
# import djaugustin_ORL_2018
# import lukebabbitt_TOT_2018
# import lukebabbitt_ATL_2018
# import lukebabbitt_MIA_2018
# import dwaynebacon_CHO_2018
# import ronbaker_NYK_2018
# import wadebaldwin_POR_2018
# import lonzoball_LAL_2018
# import jjbarea_DAL_2018
# import harrisonbarnes_DAL_2018
# import willbarton_DEN_2018
# import nicolasbatum_CHO_2018
# import jerrydbayless_PHI_2018
# import aronbaynes_BOS_2018
# import kentbazemore_ATL_2018
# import bradleybeal_WAS_2018
# import malikbeasley_DEN_2018
# import michaelbeasley_NYK_2018
# import marcobelinelli_TOT_2018
# import marcobelinelli_ATL_2018
# import marcobelinelli_PHI_2018
# import jordanbell_GSW_2018
# import deandrebembry_ATL_2018
# import draganbender_PHO_2018
# import davisbertans_SAS_2018
# import patrickbeverley_LAC_2018
# import khembirch_ORL_2018
# import jabaribird_BOS_2018
# import bismackbiyombo_ORL_2018
# import nemanjabjelica_MIN_2018
# import tarikblack_HOU_2018
# import antonioblakeney_CHI_2018
# import ericbledsoe_TOT_2018
# import ericbledsoe_PHO_2018
# import ericbledsoe_MIL_2018
# import vanderblue_LAL_2018
# import bogdanbogdanovic_SAC_2018
# import bojanbogdanovic_IND_2018
# import andrewbogut_LAL_2018
# import joelbolomboy_MIL_2018
# import devinbooker_PHO_2018
# import trevorbooker_TOT_2018
# import trevorbooker_BRK_2018
# import trevorbooker_PHI_2018
# import trevorbooker_IND_2018
# import chrisboucher_GSW_2018
# import averybradley_TOT_2018
# import averybradley_DET_2018
# import averybradley_LAC_2018
# import tonybradley_UTA_2018
# import coreybrewer_TOT_2018
# import coreybrewer_LAL_2018
# import coreybrewer_OKC_2018
# import malcolmbrogdon_MIL_2018
# import aaronbrooks_MIN_2018
# import dillonbrooks_MEM_2018
# import marshonbrooks_MEM_2018
# import anthonybrown_MIN_2018
# import bobbybrown_HOU_2018
# import jaylenbrown_BOS_2018
# import lorenzobrown_TOR_2018
# import markelbrown_HOU_2018
# import sterlingbrown_MIL_2018
# import nicolasbrussino_ATL_2018
# import thomasbryant_LAL_2018
# import reggiebullock_DET_2018
# import treyburke_NYK_2018
# import alecburks_UTA_2018
# import jimmybutler_MIN_2018
# import dwightbuycks_DET_2018
# import brunocaboclo_TOT_2018
# import brunocaboclo_TOR_2018
# import brunocaboclo_SAC_2018
# import josecalderon_CLE_2018
# import kentaviouscaldwellpope_LAL_2018
# import isaiahcanaan_TOT_2018
# import isaiahcanaan_HOU_2018
# import isaiahcanaan_PHO_2018
# import clintcapela_HOU_2018
# import demarrecarroll_BRK_2018
# import vincecarter_SAC_2018
# import michaelcarterwilliams_CHO_2018
# import alexcaruso_LAL_2018
# import omricasspi_GSW_2018
# import williecauleystein_SAC_2018
# import tylercavanaugh_ATL_2018
# import mariochalmers_MEM_2018
# import tysonchandler_PHO_2018
# import wilsonchandler_DEN_2018
# import marquesechriss_PHO_2018
# import ianclark_NOP_2018
# import jordanclarkson_TOT_2018
# import jordanclarkson_LAL_2018
# import jordanclarkson_CLE_2018
# import gianclavell_DAL_2018
# import antoniuscleveland_TOT_2018
# import antoniuscleveland_DAL_2018
# import antoniuscleveland_ATL_2018
# import johncollins_ATL_2018
# import zachcollins_POR_2018
# import kylecollinsworth_DAL_2018
# import darrencollison_IND_2018
# import nickcollison_OKC_2018
# import mikeconley_MEM_2018
# import patconnaughton_POR_2018
# import quinncook_GSW_2018
# import charlescooke_NOP_2018
# import jackcooley_SAC_2018
# import mattcostello_SAS_2018
# import demarcuscousins_NOP_2018
# import robertcovington_PHI_2018
# import allencrabbe_BRK_2018
# import torreycraig_DEN_2018
# import jamalcrawford_MIN_2018
# import jordancrawford_NOP_2018
# import jaecrowder_TOT_2018
# import jaecrowder_CLE_2018
# import jaecrowder_UTA_2018
# import dantecunningham_TOT_2018
# import dantecunningham_NOP_2018
# import dantecunningham_BRK_2018
# import stephencurry_GSW_2018
# import troydaniels_PHO_2018
# import anthonydavis_NOP_2018
# import deyontadavis_MEM_2018
# import eddavis_POR_2018
# import dewaynededmon_ATL_2018
# import samdekker_LAC_2018
# import malcolmdelaney_ATL_2018
# import matthewdellavedova_MIL_2018
# import luoldeng_LAL_2018
# import demarderozan_TOR_2018
# import cheickdiallo_NOP_2018
# import gorguidieng_MIN_2018
# import spencerdinwiddie_BRK_2018
# import tylerdorsey_ATL_2018
# import damyeandotson_NYK_2018
# import miltondoyle_BRK_2018
# import pjdozier_OKC_2018
# import gorandragic_MIA_2018
# import larrydrew_TOT_2018
# import larrydrew_PHI_2018
# import larrydrew_NOP_2018
# import andredrummond_DET_2018
# import jareddudley_PHO_2018
# import krisdunn_CHI_2018
# import kevindurant_GSW_2018
# import jarelleddie_TOT_2018
# import jarelleddie_BOS_2018
# import jarelleddie_CHI_2018
# import henryellenson_DET_2018
# import wayneellington_MIA_2018
# import joelembiid_PHI_2018
# import jamesennis_TOT_2018
# import jamesennis_MEM_2018
# import jamesennis_DET_2018
# import tylerennis_LAL_2018
# import jawunevans_LAC_2018
# import jeremyevans_ATL_2018
# import tyrekeevans_MEM_2018
# import danteexum_UTA_2018
# import kennethfaried_DEN_2018
# import derrickfavors_UTA_2018
# import kayfelder_TOT_2018
# import kayfelder_CHI_2018
# import kayfelder_DET_2018
# import cristianofelicio_CHI_2018
# import raymondfelton_OKC_2018
# import terranceferguson_OKC_2018
# import yogiferrell_DAL_2018
# import dorianfinneysmith_DAL_2018
# import brynforbes_SAS_2018
# import evanfournier_ORL_2018
# import deaaronfox_SAC_2018
# import timfrazier_WAS_2018
# import channingfrye_TOT_2018
# import channingfrye_CLE_2018
# import channingfrye_LAL_2018
# import markellefultz_PHI_2018
# import danilogallinari_LAC_2018
# import langstongalloway_DET_2018
# import marcgasol_MEM_2018
# import paugasol_SAS_2018
# import rudygay_SAS_2018
# import paulgeorge_OKC_2018
# import marcusgeorgeshunt_MIN_2018
# import jonathangibson_BOS_2018
# import tajgibson_MIN_2018
# import manuginobili_SAS_2018
# import rudygobert_UTA_2018
# import aarongordon_ORL_2018
# import ericgordon_HOU_2018
# import marcingortat_WAS_2018
# import treveongraham_CHO_2018
# import jeramigrant_OKC_2018
# import jeriangrant_CHI_2018
# import joshgray_PHO_2018
# import dannygreen_SAS_2018
# import draymondgreen_GSW_2018
# import geraldgreen_HOU_2018
# import jamychalgreen_MEM_2018
# import jeffgreen_CLE_2018
# import blakegriffin_TOT_2018
# import blakegriffin_LAC_2018
# import blakegriffin_DET_2018
# import danielhamilton_OKC_2018
# import timhardaway_NYK_2018
# import jamesharden_HOU_2018
# import mauriceharkless_POR_2018
# import montrezlharrell_LAC_2018
# import devinharris_TOT_2018
# import devinharris_DAL_2018
# import devinharris_DEN_2018
# import garyharris_DEN_2018
# import joeharris_BRK_2018
# import tobiasharris_TOT_2018
# import tobiasharris_DET_2018
# import tobiasharris_LAC_2018
# import aaronharrison_DAL_2018
# import andrewharrison_MEM_2018
# import shaquilleharrison_PHO_2018
# import joshhart_LAL_2018
# import udonishaslem_MIA_2018
# import nigelhayes_TOT_2018
# import nigelhayes_LAL_2018
# import nigelhayes_TOR_2018
# import nigelhayes_SAC_2018
# import gordonhayward_BOS_2018
# import reggiehearn_DET_2018
# import mykehenry_MEM_2018
# import johnhenson_MIL_2018
# import juanhernangomez_DEN_2018
# import willyhernangomez_TOT_2018
# import willyhernangomez_NYK_2018
# import willyhernangomez_CHO_2018
# import mariohezonja_ORL_2018
# import isaiahhicks_NYK_2018
# import buddyhield_SAC_2018
# import nenehilario_HOU_2018
# import georgehill_TOT_2018
# import georgehill_SAC_2018
# import georgehill_CLE_2018
# import solomonhill_NOP_2018
# import darrunhilliard_SAS_2018
# import jrueholiday_NOP_2018
# import justinholiday_CHI_2018
# import johnholland_CLE_2018
# import rondaehollisjefferson_BRK_2018
# import richaunholmes_PHI_2018
# import rodneyhood_TOT_2018
# import rodneyhood_UTA_2018
# import rodneyhood_CLE_2018
# import scottyhopson_DAL_2018
# import alhorford_BOS_2018
# import danuelhouse_PHO_2018
# import dwighthoward_CHO_2018
# import joshhuestis_OKC_2018
# import rjhunter_HOU_2018
# import vincehunter_MEM_2018
# import sergeibaka_TOR_2018
# import andreiguodala_GSW_2018
# import ersanilyasova_TOT_2018
# import ersanilyasova_ATL_2018
# import ersanilyasova_PHI_2018
# import joeingles_UTA_2018
# import andreingram_LAL_2018
# import brandoningram_LAL_2018
# import kyrieirving_BOS_2018
# import jonathanisaac_ORL_2018
# import wesleyiwundu_ORL_2018
# import jarrettjack_NYK_2018
# import aaronjackson_HOU_2018
# import demetriusjackson_TOT_2018
# import demetriusjackson_HOU_2018
# import demetriusjackson_PHI_2018
# import joshjackson_PHO_2018
# import justinjackson_SAC_2018
# import reggiejackson_DET_2018
# import lebronjames_CLE_2018
# import mikejames_TOT_2018
# import mikejames_PHO_2018
# import mikejames_NOP_2018
# import aljefferson_IND_2018
# import richardjefferson_DEN_2018
# import brandonjennings_MIL_2018
# import jonasjerebko_UTA_2018
# import amirjohnson_PHI_2018
# import bricejohnson_TOT_2018
# import bricejohnson_LAC_2018
# import bricejohnson_MEM_2018
# import dakarijohnson_OKC_2018
# import jamesjohnson_MIA_2018
# import joejohnson_TOT_2018
# import joejohnson_UTA_2018
# import joejohnson_HOU_2018
# import omarijohnson_MEM_2018
# import stanleyjohnson_DET_2018
# import tylerjohnson_MIA_2018
# import wesleyjohnson_LAC_2018
# import nikolajokic_DEN_2018
# import damianjones_GSW_2018
# import derrickjones_TOT_2018
# import derrickjones_PHO_2018
# import derrickjones_MIA_2018
# import jalenjones_TOT_2018
# import jalenjones_NOP_2018
# import jalenjones_DAL_2018
# import tyusjones_MIN_2018
# import deandrejordan_LAC_2018
# import coryjoseph_IND_2018
# import frankkaminsky_CHO_2018
# import eneskanter_NYK_2018
# import lukekennard_DET_2018
# import michaelkiddgilchrist_CHO_2018
# import seankilpatrick_TOT_2018
# import seankilpatrick_BRK_2018
# import seankilpatrick_MIL_2018
# import seankilpatrick_LAC_2018
# import seankilpatrick_CHI_2018
# import maxikleber_DAL_2018
# import furkankorkmaz_PHI_2018
# import lukekornet_NYK_2018
# import kylekorver_CLE_2018
# import kostakoufos_SAC_2018
# import kylekuzma_LAL_2018
# import mindaugaskuzminskas_NYK_2018
# import skallabissiere_SAC_2018
# import jeremylamb_CHO_2018
# import shanelarkin_BOS_2018
# import joffreylauvergne_SAS_2018
# import zachlavine_CHI_2018
# import jakelayman_POR_2018
# import tjleaf_IND_2018
# import courtneylee_NYK_2018
# import damionlee_ATL_2018
# import waltlemonjr_NOP_2018
# import alexlen_PHO_2018
# import kawhileonard_SAS_2018
# import meyersleonard_POR_2018
# import jonleuer_DET_2018
# import carislevert_BRK_2018
# import deandreliggins_TOT_2018
# import deandreliggins_MIL_2018
# import deandreliggins_NOP_2018
# import damianlillard_POR_2018
# import jeremylin_BRK_2018
# import shaunlivingston_GSW_2018
# import kevonlooney_GSW_2018
# import brooklopez_LAL_2018
# import robinlopez_CHI_2018
# import kevinlove_CLE_2018
# import kylelowry_TOR_2018
# import timotheluwawucabarrot_PHI_2018
# import tylerlydon_DEN_2018
# import treylyles_DEN_2018
# import shelvinmack_ORL_2018
# import joshmagette_ATL_2018
# import ianmahinmi_WAS_2018
# import thonmaker_MIL_2018
# import bobanmarjanovic_TOT_2018
# import bobanmarjanovic_DET_2018
# import bobanmarjanovic_LAC_2018
# import laurimarkkanen_CHI_2018
# import jarellmartin_MEM_2018
# import frankmason_SAC_2018
# import mangokmathiang_CHO_2018
# import wesleymatthews_DAL_2018
# import lucmbahamoute_HOU_2018
# import jamesmichaelmcadoo_PHI_2018
# import patrickmccaw_GSW_2018
# import cjmccollum_POR_2018
# import tjmcconnell_PHI_2018
# import erikmccree_UTA_2018
# import chrismccullough_WAS_2018
# import dougmcdermott_TOT_2018
# import dougmcdermott_NYK_2018
# import dougmcdermott_DAL_2018
# import javalemcgee_GSW_2018
# import rodneymcgruder_MIA_2018
# import treymckinneyjones_IND_2018
# import alfonzomckinnie_TOR_2018
# import benmclemore_MEM_2018
# import joshmcroberts_DAL_2018
# import jodiemeeks_WAS_2018
# import salahmejri_DAL_2018
# import jordanmickey_MIA_2018
# import khrismiddleton_MIL_2018
# import cjmiles_TOR_2018
# import dariusmiller_NOP_2018
# import malcolmmiller_TOR_2018
# import pattymills_SAS_2018
# import paulmillsap_DEN_2018
# import nikolamirotic_TOT_2018
# import nikolamirotic_CHI_2018
# import nikolamirotic_NOP_2018
# import donovanmitchell_UTA_2018
# import nazmitroulong_UTA_2018
# import malikmonk_CHO_2018
# import gregmonroe_TOT_2018
# import gregmonroe_MIL_2018
# import gregmonroe_PHO_2018
# import gregmonroe_BOS_2018
# import luismontero_DET_2018
# import benmoore_IND_2018
# import etwaunmoore_NOP_2018
# import ericmoreland_DET_2018
# import jaylenmorris_ATL_2018
# import marcusmorris_BOS_2018
# import markieffmorris_WAS_2018
# import montemorris_DEN_2018
# import johnathanmotley_DAL_2018
# import timofeymozgov_BRK_2018
# import emmanuelmudiay_TOT_2018
# import emmanuelmudiay_DEN_2018
# import emmanuelmudiay_NYK_2018
# import shabazzmuhammad_TOT_2018
# import shabazzmuhammad_MIN_2018
# import shabazzmuhammad_MIL_2018
# import xaviermunford_MIL_2018
# import dejountemurray_SAS_2018
# import jamalmurray_DEN_2018
# import mikemuscala_ATL_2018
# import abdelnader_BOS_2018
# import larrynance_TOT_2018
# import larrynance_LAL_2018
# import larrynance_CLE_2018
# import shabazznapier_POR_2018
# import jameernelson_TOT_2018
# import jameernelson_NOP_2018
# import jameernelson_DET_2018
# import raulneto_UTA_2018
# import georgesniang_UTA_2018
# import joakimnoah_NYK_2018
# import nerlensnoel_DAL_2018
# import lucasnogueira_TOR_2018
# import dirknowitzki_DAL_2018
# import frankntilikina_NYK_2018
# import jusufnurkic_POR_2018
# import davidnwaba_CHI_2018
# import johnnyobryant_CHO_2018
# import royceoneale_UTA_2018
# import kyleoquinn_NYK_2018
# import semiojeleye_BOS_2018
# import emekaokafor_NOP_2018
# import jahlilokafor_TOT_2018
# import jahlilokafor_PHI_2018
# import jahlilokafor_BRK_2018
# import victoroladipo_IND_2018
# import kellyolynyk_MIA_2018
# import chinanuonuaku_HOU_2018
# import cediosman_CLE_2018
# import kellyoubre_WAS_2018
# import zazapachulia_GSW_2018
# import marcuspaige_CHO_2018
# import georgiospapagiannis_TOT_2018
# import georgiospapagiannis_SAC_2018
# import georgiospapagiannis_POR_2018
# import jabariparker_MIL_2018
# import tonyparker_SAS_2018
# import chandlerparsons_MEM_2018
# import patrickpatterson_OKC_2018
# import justinpatton_MIN_2018
# import brandonpaul_SAS_2018
# import chrispaul_HOU_2018
# import adreianpayne_ORL_2018
# import cameronpayne_CHI_2018
# import elfridpayton_TOT_2018
# import elfridpayton_ORL_2018
# import elfridpayton_PHO_2018
# import garypayton_TOT_2018
# import garypayton_MIL_2018
# import garypayton_LAL_2018
# import kendrickperkins_CLE_2018
# import londonperrantes_CLE_2018
# import alecpeters_PHO_2018
# import marshallplumlee_MIL_2018
# import masonplumlee_DEN_2018
# import milesplumlee_ATL_2018
# import jakobpoeltl_TOR_2018
# import quincypondexter_CHI_2018
# import ottoporter_WAS_2018
# import bobbyportis_CHI_2018
# import kristapsporzingis_NYK_2018
# import dwightpowell_DAL_2018
# import normanpowell_TOR_2018
# import alexpoythress_IND_2018
# import jacobpullen_PHI_2018
# import rodneypurvis_ORL_2018
# import zhouqi_HOU_2018
# import timquarterman_HOU_2018
# import ivanrabb_MEM_2018
# import juliusrandle_LAL_2018
# import zachrandolph_SAC_2018
# import xavierrathanmayes_MEM_2018
# import jjredick_PHI_2018
# import davonreed_PHO_2018
# import williereed_TOT_2018
# import williereed_LAC_2018
# import williereed_DET_2018
# import joshrichardson_MIA_2018
# import malachirichardson_TOT_2018
# import malachirichardson_SAC_2018
# import malachirichardson_TOR_2018
# import austinrivers_LAC_2018
# import andreroberson_OKC_2018
# import devinrobinson_WAS_2018
# import glennrobinson_IND_2018
# import rajonrondo_NOP_2018
# import derrickrose_TOT_2018
# import derrickrose_CLE_2018
# import derrickrose_MIN_2018
# import terrenceross_ORL_2018
# import terryrozier_BOS_2018
# import rickyrubio_UTA_2018
# import dangelorussell_BRK_2018
# import domantassabonis_IND_2018
# import jakarrsampson_SAC_2018
# import dariosaric_PHI_2018
# import tomassatoransky_WAS_2018
# import dennisschroder_ATL_2018
# import mikescott_WAS_2018
# import thabosefolosha_UTA_2018
# import wayneselden_MEM_2018
# import ramonsessions_TOT_2018
# import ramonsessions_NYK_2018
# import ramonsessions_WAS_2018
# import imanshumpert_CLE_2018
# import pascalsiakam_TOR_2018
# import xaviersilas_BOS_2018
# import bensimmons_PHI_2018
# import jonathonsimmons_ORL_2018
# import kobisimmons_MEM_2018
# import kylesingler_OKC_2018
# import marcussmart_BOS_2018
# import dennissmith_DAL_2018
# import ishsmith_DET_2018
# import jrsmith_CLE_2018
# import jasonsmith_WAS_2018
# import joshsmith_NOP_2018
# import tonysnell_MIL_2018
# import marreesespeights_ORL_2018
# import nikstauskas_TOT_2018
# import nikstauskas_PHI_2018
# import nikstauskas_BRK_2018
# import lancestephenson_IND_2018
# import davidstockton_UTA_2018
# import julyanstone_CHO_2018
# import edmondsumner_IND_2018
# import calebswanigan_POR_2018
# import jaysontatum_BOS_2018
# import isaiahtaylor_ATL_2018
# import jeffteague_MIN_2018
# import marquisteague_MEM_2018
# import mirzateletovic_MIL_2018
# import garretttemple_SAC_2018
# import milosteodosic_LAC_2018
# import jasonterry_MIL_2018
# import danieltheis_BOS_2018
# import isaiahthomas_TOT_2018
# import isaiahthomas_CLE_2018
# import isaiahthomas_LAL_2018
# import lancethomas_NYK_2018
# import klaythompson_GSW_2018
# import tristanthompson_CLE_2018
# import sindariusthornwell_LAC_2018
# import anthonytolliver_DET_2018
# import karlanthonytowns_MIN_2018
# import pjtucker_HOU_2018
# import evanturner_POR_2018
# import mylesturner_IND_2018
# import ekpeudoh_UTA_2018
# import tylerulis_PHO_2018
# import jonasvalanciunas_TOR_2018
# import denzelvalentine_CHI_2018
# import fredvanvleet_TOR_2018
# import rashadvaughn_TOT_2018
# import rashadvaughn_MIL_2018
# import rashadvaughn_BRK_2018
# import rashadvaughn_ORL_2018
# import noahvonleh_TOT_2018
# import noahvonleh_POR_2018
# import noahvonleh_CHI_2018
# import nikolavucevic_ORL_2018
# import dwyanewade_TOT_2018
# import dwyanewade_CLE_2018
# import dwyanewade_MIA_2018
# import dionwaiters_MIA_2018
# import kembawalker_CHO_2018
# import johnwall_WAS_2018
# import tyronewallace_LAC_2018
# import taureanwallerprince_ATL_2018
# import derrickwalton_MIA_2018
# import jameelwarney_DAL_2018
# import tjwarren_PHO_2018
# import traviswear_LAL_2018
# import jameswebb_BRK_2018
# import brianteweber_TOT_2018
# import brianteweber_HOU_2018
# import brianteweber_MEM_2018
# import davidwest_GSW_2018
# import russellwestbrook_OKC_2018
# import andrewwhite_ATL_2018
# import derrickwhite_SAS_2018
# import okarowhite_MIA_2018
# import isaiahwhitehead_BRK_2018
# import hassanwhiteside_MIA_2018
# import andrewwiggins_MIN_2018
# import jacobwiley_BRK_2018
# import damienwilkins_IND_2018
# import alanwilliams_PHO_2018
# import cjwilliams_LAC_2018
# import derrickwilliams_LAL_2018
# import louwilliams_LAC_2018
# import marvinwilliams_CHO_2018
# import mattwilliams_MIA_2018
# import troywilliams_TOT_2018
# import troywilliams_HOU_2018
# import troywilliams_NYK_2018
# import djwilson_MIL_2018
# import jamilwilson_LAC_2018
# import justisewinslow_MIA_2018
# import jeffwithey_DAL_2018
# import natewolters_UTA_2018
# import brandanwright_TOT_2018
# import brandanwright_MEM_2018
# import brandanwright_HOU_2018
# import delonwright_TOR_2018
# import guerschonyabusele_BOS_2018
# import jamesyoung_PHI_2018
# import joeyoung_IND_2018
# import nickyoung_GSW_2018
# import thaddeusyoung_IND_2018
# import codyzeller_CHO_2018
# import tylerzeller_TOT_2018
# import tylerzeller_BRK_2018
# import tylerzeller_MIL_2018
# import paulzipser_CHI_2018
# import antezizic_CLE_2018
# import ivicazubac_LAL_2018
# creating index
# index created (or already existed)
# 30
# could not convert string to float: HOU
# could not convert string to float: Houston Rockets
# could not convert string to float: Toyota Center
# invalid literal for float(): 732,722
# invalid literal for float(): 17,871
# 2018.0_Houston Rockets
# could not convert string to float: TOR
# could not convert string to float: Toronto Raptors
# could not convert string to float: Air Canada Centre
# invalid literal for float(): 813,431
# invalid literal for float(): 19,840
# 2018.0_Toronto Raptors
# could not convert string to float: GSW
# could not convert string to float: Golden State Warriors
# could not convert string to float: Oracle Arena
# invalid literal for float(): 803,436
# invalid literal for float(): 19,596
# 2018.0_Golden State Warriors
# could not convert string to float: UTA
# could not convert string to float: Utah Jazz
# could not convert string to float: Vivint Smart Home Arena
# invalid literal for float(): 734,806
# invalid literal for float(): 17,922
# 2018.0_Utah Jazz
# could not convert string to float: PHI
# could not convert string to float: Philadelphia 76ers
# could not convert string to float: Wells Fargo Center
# invalid literal for float(): 833,503
# invalid literal for float(): 20,361
# 2018.0_Philadelphia 76ers
# could not convert string to float: OKC
# could not convert string to float: Oklahoma City Thunder
# could not convert string to float: Chesapeake Energy Arena
# invalid literal for float(): 746,322
# invalid literal for float(): 18,203
# 2018.0_Oklahoma City Thunder
# could not convert string to float: BOS
# could not convert string to float: Boston Celtics
# could not convert string to float: TD Garden
# invalid literal for float(): 763,584
# invalid literal for float(): 18,624
# 2018.0_Boston Celtics
# could not convert string to float: SAS
# could not convert string to float: San Antonio Spurs
# could not convert string to float: AT&T Center
# invalid literal for float(): 754,562
# invalid literal for float(): 18,404
# 2018.0_San Antonio Spurs
# could not convert string to float: POR
# could not convert string to float: Portland Trail Blazers
# could not convert string to float: Moda Center
# invalid literal for float(): 795,750
# invalid literal for float(): 19,409
# 2018.0_Portland Trail Blazers
# could not convert string to float: MIN
# could not convert string to float: Minnesota Timberwolves
# could not convert string to float: Target Center
# invalid literal for float(): 699,308
# invalid literal for float(): 17,056
# 2018.0_Minnesota Timberwolves
# could not convert string to float: DEN
# could not convert string to float: Denver Nuggets
# could not convert string to float: Pepsi Center
# invalid literal for float(): 702,796
# invalid literal for float(): 17,141
# 2018.0_Denver Nuggets
# could not convert string to float: NOP
# could not convert string to float: New Orleans Pelicans
# could not convert string to float: Smoothie King Center
# invalid literal for float(): 673,920
# invalid literal for float(): 16,437
# 2018.0_New Orleans Pelicans
# could not convert string to float: IND
# could not convert string to float: Indiana Pacers
# could not convert string to float: Bankers Life Fieldhouse
# invalid literal for float(): 658,119
# invalid literal for float(): 16,052
# 2018.0_Indiana Pacers
# could not convert string to float: CLE
# could not convert string to float: Cleveland Cavaliers
# could not convert string to float: Quicken Loans Arena
# invalid literal for float(): 843,042
# invalid literal for float(): 20,562
# 2018.0_Cleveland Cavaliers
# could not convert string to float: WAS
# could not convert string to float: Washington Wizards
# could not convert string to float: Capital One Arena
# invalid literal for float(): 739,302
# invalid literal for float(): 18,032
# 2018.0_Washington Wizards
# could not convert string to float: LAC
# could not convert string to float: Los Angeles Clippers
# could not convert string to float: STAPLES Center
# invalid literal for float(): 697,812
# invalid literal for float(): 17,020
# 2018.0_Los Angeles Clippers
# could not convert string to float: MIA
# could not convert string to float: Miami Heat
# could not convert string to float: AmericanAirlines Arena
# invalid literal for float(): 804,850
# invalid literal for float(): 19,630
# 2018.0_Miami Heat
# could not convert string to float: CHO
# could not convert string to float: Charlotte Hornets
# could not convert string to float: Spectrum Center
# invalid literal for float(): 671,404
# invalid literal for float(): 16,376
# 2018.0_Charlotte Hornets
# could not convert string to float: DET
# could not convert string to float: Detroit Pistons
# could not convert string to float: Little Caesars Arena
# invalid literal for float(): 713,945
# invalid literal for float(): 17,413
# 2018.0_Detroit Pistons
# could not convert string to float: MIL
# could not convert string to float: Milwaukee Bucks
# could not convert string to float: BMO Harris Bradley Center
# invalid literal for float(): 685,303
# invalid literal for float(): 16,856
# 2018.0_Milwaukee Bucks
# could not convert string to float: LAL
# could not convert string to float: Los Angeles Lakers
# could not convert string to float: STAPLES Center
# invalid literal for float(): 776,327
# invalid literal for float(): 18,935
# 2018.0_Los Angeles Lakers
# could not convert string to float: DAL
# could not convert string to float: Dallas Mavericks
# could not convert string to float: American Airlines Center
# invalid literal for float(): 811,453
# invalid literal for float(): 19,792
# 2018.0_Dallas Mavericks
# could not convert string to float: NYK
# could not convert string to float: New York Knicks
# could not convert string to float: Madison Square Garden (IV)
# invalid literal for float(): 792,608
# invalid literal for float(): 19,332
# 2018.0_New York Knicks
# could not convert string to float: BRK
# could not convert string to float: Brooklyn Nets
# could not convert string to float: Barclays Center
# invalid literal for float(): 640,010
# invalid literal for float(): 15,376
# 2018.0_Brooklyn Nets
# could not convert string to float: ORL
# could not convert string to float: Orlando Magic
# could not convert string to float: Amway Center
# invalid literal for float(): 734,531
# invalid literal for float(): 17,915
# 2018.0_Orlando Magic
# could not convert string to float: ATL
# could not convert string to float: Atlanta Hawks
# could not convert string to float: Philips Arena
# invalid literal for float(): 590,769
# invalid literal for float(): 14,409
# 2018.0_Atlanta Hawks
# could not convert string to float: MEM
# could not convert string to float: Memphis Grizzlies
# could not convert string to float: FedEx Forum
# invalid literal for float(): 653,863
# invalid literal for float(): 15,948
# 2018.0_Memphis Grizzlies
# could not convert string to float: SAC
# could not convert string to float: Sacramento Kings
# could not convert string to float: Golden 1 Center
# invalid literal for float(): 714,680
# invalid literal for float(): 17,431
# 2018.0_Sacramento Kings
# could not convert string to float: CHI
# could not convert string to float: Chicago Bulls
# could not convert string to float: United Center
# invalid literal for float(): 851,824
# invalid literal for float(): 20,776
# 2018.0_Chicago Bulls
# could not convert string to float: PHO
# could not convert string to float: Phoenix Suns
# could not convert string to float: Talking Stick Resort Arena
# invalid literal for float(): 690,576
# invalid literal for float(): 16,843
# 2018.0_Phoenix Suns
# Added RPM for Chris Paul
# Added RPM for James Harden
# Added RPM for Stephen Curry
# Added RPM for Jimmy Butler
# Added RPM for Nikola Jokic
# Added RPM for Victor Oladipo
# Added RPM for Anthony Davis
# Added RPM for Robert Covington
# Added RPM for Kyle Lowry
# Added RPM for Russell Westbrook
# Added RPM for Joel Embiid
# Added RPM for LeBron James
# [WAS] Otto Porter Jr.'s name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is ottoporterjr
# 	Converted Otto Porter Jr. to Otto Porter
# Added RPM for Otto Porter
# Added RPM for Damian Lillard
# Added RPM for Tyus Jones
# Added RPM for Karl-Anthony Towns
# Added RPM for Giannis Antetokounmpo
# Added RPM for Draymond Green
# Added RPM for Al Horford
# Added RPM for Rudy Gobert
# Added RPM for Kemba Walker
# Added RPM for Jrue Holiday
# Added RPM for DeMarcus Cousins
# Added RPM for Kevin Durant
# Added RPM for Joe Ingles
# Added RPM for Tyreke Evans
# Added RPM for Kevin Love
# Added RPM for Fred VanVleet
# Added RPM for Kelly Olynyk
# Added RPM for Nikola Mirotic
# Added RPM for Nikola Mirotic
# Added RPM for LaMarcus Aldridge
# Added RPM for Kyle Anderson
# Added RPM for Jayson Tatum
# Added RPM for Paul George
# Added RPM for Ben Simmons
# Added RPM for Nene Hilario
# Added RPM for Jordan Bell
# Added RPM for Kyle Korver
# Added RPM for Kristaps Porzingis
# [CLE] Larry Nance Jr.'s name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is larrynancejr
# 	Converted Larry Nance Jr. to Larry Nance
# Added RPM for Larry Nance
# Added RPM for Larry Nance
# Added RPM for Eric Bledsoe
# Added RPM for Eric Bledsoe
# Added RPM for Dwight Powell
# Added RPM for Spencer Dinwiddie
# Added RPM for Ricky Rubio
# Added RPM for Kyrie Irving
# Added RPM for David West
# Added RPM for Ekpe Udoh
# Added RPM for Darren Collison
# Added RPM for Nikola Vucevic
# Added RPM for Donovan Mitchell
# Added RPM for Clint Capela
# Added RPM for Blake Griffin
# Added RPM for Blake Griffin
# Added RPM for Al-Farouq Aminu
# Added RPM for Eric Gordon
# Added RPM for Salah Mejri
# Added RPM for Kyle O'Quinn
# Added RPM for Tomas Satoransky
# Added RPM for Dirk Nowitzki
# Added RPM for Gary Harris
# Added RPM for Klay Thompson
# Added RPM for Jusuf Nurkic
# Added RPM for Amir Johnson
# Added RPM for Andre Roberson
# Added RPM for Dejounte Murray
# Added RPM for Lucas Nogueira
# Added RPM for DeMar DeRozan
# Added RPM for Trevor Ariza
# Added RPM for DeMarre Carroll
# Added RPM for Davis Bertans
# Added RPM for Delon Wright
# Added RPM for Marc Gasol
# Added RPM for Paul Millsap
# Added RPM for Pascal Siakam
# Added RPM for Marvin Williams
# Added RPM for Zaza Pachulia
# Added RPM for Andre Drummond
# Added RPM for Andre Iguodala
# Added RPM for Khris Middleton
# Added RPM for Steven Adams
# Added RPM for Jaylen Brown
# Added RPM for James Johnson
# Added RPM for Thabo Sefolosha
# Added RPM for Kevon Looney
# Added RPM for Tobias Harris
# Added RPM for Tobias Harris
# Added RPM for Bradley Beal
# Added RPM for Terry Rozier
# Added RPM for PJ Tucker
# Added RPM for Kent Bazemore
# Added RPM for John Wall
# Added RPM for Lonzo Ball
# Added RPM for Thaddeus Young
# Added RPM for Yogi Ferrell
# Added RPM for Marreese Speights
# Added RPM for Justin Holiday
# Added RPM for Ed Davis
# Added RPM for Pau Gasol
# Added RPM for Jonas Valanciunas
# Added RPM for Jeremy Lamb
# Added RPM for Boban Marjanovic
# Added RPM for Boban Marjanovic
# Added RPM for Nemanja Bjelica
# Added RPM for Josh Richardson
# Added RPM for Marcus Smart
# Added RPM for Ersan Ilyasova
# Added RPM for Ersan Ilyasova
# Added RPM for Luc Mbah a Moute
# Added RPM for Royce O'Neale
# Added RPM for Kawhi Leonard
# Added RPM for Jose Calderon
# Added RPM for Langston Galloway
# [NYK] Tim Hardaway Jr.'s name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is timhardawayjr
# 	Converted Tim Hardaway Jr. to Tim Hardaway
# Added RPM for Tim Hardaway
# Added RPM for Will Barton
# Added RPM for Aaron Gordon
# Added RPM for Anthony Tolliver
# Added RPM for Montrezl Harrell
# Added RPM for Jeff Teague
# Added RPM for Serge Ibaka
# Added RPM for Dwight Howard
# Added RPM for Channing Frye
# Added RPM for Channing Frye
# Added RPM for John Henson
# Added RPM for Lou Williams
# Added RPM for Dewayne Dedmon
# Added RPM for OG Anunoby
# Added RPM for Julius Randle
# Added RPM for DeAndre Jordan
# Added RPM for Kentavious Caldwell-Pope
# Added RPM for JJ Redick
# Added RPM for Aron Baynes
# Added RPM for Jonas Jerebko
# Added RPM for Derrick Favors
# Added RPM for Brandan Wright
# Added RPM for Brandan Wright
# Added RPM for Hassan Whiteside
# [DAL] Maximilian Kleber's name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is maximiliankleber
# 	Found harded coded version from Maximilian Kleber to Maxi Kleber
# Added RPM for Maxi Kleber
# Added RPM for George Hill
# Added RPM for George Hill
# Added RPM for Jakob Poeltl
# Added RPM for Mike Muscala
# Added RPM for Myles Turner
# Added RPM for Shabazz Napier
# Added RPM for Willy Hernangomez
# Added RPM for Willy Hernangomez
# Added RPM for Goran Dragic
# Added RPM for Daniel Theis
# Added RPM for Dakari Johnson
# Added RPM for Dario Saric
# Added RPM for Devin Harris
# Added RPM for Devin Harris
# Added RPM for Brook Lopez
# Added RPM for Jamal Murray
# Added RPM for Jamil Wilson
# Added RPM for Justise Winslow
# Added RPM for Rudy Gay
# Added RPM for Omri Casspi
# Added RPM for Eric Moreland
# Added RPM for Jeff Green
# Added RPM for Taj Gibson
# Added RPM for Shaquille Harrison
# Added RPM for Andrew Bogut
# Added RPM for Willie Reed
# Added RPM for Willie Reed
# Added RPM for D.J. Augustin
# Added RPM for Danny Green
# Added RPM for Evan Fournier
# Added RPM for Marcin Gortat
# Added RPM for Jared Dudley
# Added RPM for Mario Chalmers
# Added RPM for Cody Zeller
# Added RPM for Reggie Bullock
# Added RPM for Raul Neto
# Added RPM for Enes Kanter
# Added RPM for Alan Williams
# Added RPM for Trey Lyles
# Added RPM for Kendrick Perkins
# Added RPM for Vince Carter
# Added RPM for Buddy Hield
# Added RPM for Domantas Sabonis
# Added RPM for JaKarr Sampson
# Added RPM for Milos Teodosic
# Added RPM for Tyson Chandler
# Added RPM for Danilo Gallinari
# Added RPM for JaVale McGee
# Added RPM for Reggie Jackson
# Added RPM for Ish Smith
# Added RPM for CJ McCollum
# Added RPM for CJ Miles
# Added RPM for Nick Collison
# Added RPM for Meyers Leonard
# Added RPM for Wayne Ellington
# Added RPM for Ivica Zubac
# Added RPM for Marshall Plumlee
# Added RPM for Richaun Holmes
# Added RPM for Matt Costello
# Added RPM for Ron Baker
# Added RPM for Patrick Patterson
# Added RPM for Tyler Johnson
# Added RPM for Allen Crabbe
# Added RPM for John Collins
# Added RPM for Nicolas Batum
# Added RPM for Frank Kaminsky
# Added RPM for Derrick White
# Added RPM for Travis Wear
# Added RPM for Ian Mahinmi
# Added RPM for Mason Plumlee
# Added RPM for Jack Cooley
# Added RPM for Bam Adebayo
# Added RPM for Julyan Stone
# Added RPM for Jerian Grant
# Added RPM for Bobby Portis
# Added RPM for Mike Conley
# Added RPM for MarShon Brooks
# Added RPM for Isaiah Canaan
# Added RPM for Isaiah Canaan
# Added RPM for Nigel Hayes
# Added RPM for Nigel Hayes
# Added RPM for Nigel Hayes
# Added RPM for Joe Harris
# Added RPM for Khem Birch
# Added RPM for Emeka Okafor
# Added RPM for Adreian Payne
# Added RPM for Josh Hart
# Added RPM for Luke Kennard
# Added RPM for Jon Leuer
# Added RPM for Patty Mills
# Added RPM for Jameel Warney
# Added RPM for Carmelo Anthony
# Added RPM for Mangok Mathiang
# Added RPM for Jerami Grant
# Added RPM for Gerald Green
# Added RPM for Wesley Johnson
# Added RPM for Joakim Noah
# Added RPM for Al Jefferson
# Added RPM for Cory Joseph
# Added RPM for J.J. Barea
# Added RPM for Nerlens Noel
# Added RPM for Rondae Hollis-Jefferson
# Added RPM for Jarrett Jack
# Added RPM for Shelvin Mack
# Added RPM for Derrick Williams
# Added RPM for Josh McRoberts
# Added RPM for Willie Cauley-Stein
# Added RPM for Andre Ingram
# Added RPM for Cole Aldrich
# Added RPM for James Michael McAdoo
# Added RPM for Mirza Teletovic
# Added RPM for Malcolm Brogdon
# Added RPM for Devin Booker
# Added RPM for Manu Ginobili
# Added RPM for Darius Miller
# Added RPM for Jeff Withey
# Added RPM for Denzel Valentine
# Added RPM for Stanley Johnson
# Added RPM for Rajon Rondo
# Added RPM for Bojan Bogdanovic
# Added RPM for Austin Rivers
# Added RPM for Kosta Koufos
# Added RPM for Jacob Wiley
# Added RPM for Tyler Cavanaugh
# Added RPM for Trey Burke
# Added RPM for Damion Lee
# [POR] Wade Baldwin IV's name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is wadebaldwiniv
# 	Found harded coded version from Wade Baldwin IV to Wade Baldwin
# Added RPM for Wade Baldwin
# [IND] Glenn Robinson III's name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is glennrobinsoniii
# 	Found harded coded version from Glenn Robinson III to Glenn Robinson
# Added RPM for Glenn Robinson
# Added RPM for Jason Terry
# Added RPM for Udonis Haslem
# Added RPM for Cedi Osman
# Added RPM for Patrick Beverley
# Added RPM for Alex Len
# Added RPM for Ante Zizic
# Added RPM for Wilson Chandler
# Added RPM for Shane Larkin
# Added RPM for Justin Patton
# Added RPM for E'Twaun Moore
# Added RPM for Gian Clavell
# Added RPM for Timofey Mozgov
# Added RPM for Chinanu Onuaku
# Added RPM for Guerschon Yabusele
# Added RPM for Kyle Singler
# Added RPM for Mike James
# Added RPM for Mike James
# Added RPM for Dillon Brooks
# Added RPM for Tyler Zeller
# Added RPM for Tyler Zeller
# Added RPM for Kris Dunn
# Added RPM for Alec Peters
# Added RPM for Markieff Morris
# Added RPM for Courtney Lee
# Added RPM for Malcolm Miller
# Added RPM for Joel Bolomboy
# Added RPM for Thomas Bryant
# Added RPM for Michael Carter-Williams
# Added RPM for Ryan Anderson
# Added RPM for Georges Niang
# Added RPM for Jacob Pullen
# Added RPM for Maurice Harkless
# Added RPM for Omari Johnson
# Added RPM for Tyler Ennis
# Added RPM for Luol Deng
# Added RPM for Tim Frazier
# Added RPM for Naz Mitrou-Long
# Added RPM for Alex Abrines
# Added RPM for Trey McKinney-Jones
# Added RPM for Okaro White
# Added RPM for Johnathan Motley
# Added RPM for Trevor Booker
# Added RPM for Trevor Booker
# Added RPM for Trevor Booker
# Added RPM for Brice Johnson
# Added RPM for Brice Johnson
# Added RPM for Tony Bradley
# Added RPM for Rodney McGruder
# Added RPM for Kyle Collinsworth
# Added RPM for Michael Beasley
# Added RPM for Iman Shumpert
# Added RPM for Sam Dekker
# Added RPM for Gordon Hayward
# Added RPM for Pat Connaughton
# [WAS] Kelly Oubre Jr.'s name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is kellyoubrejr
# 	Converted Kelly Oubre Jr. to Kelly Oubre
# Added RPM for Kelly Oubre
# Added RPM for Caleb Swanigan
# Added RPM for Antonius Cleveland
# Added RPM for Antonius Cleveland
# Added RPM for Kyle Kuzma
# Added RPM for Nicolas Brussino
# Added RPM for Raymond Felton
# Added RPM for Luke Babbitt
# Added RPM for Luke Babbitt
# Added RPM for Kenneth Faried
# Added RPM for Damian Jones
# Added RPM for Dante Exum
# Added RPM for Cameron Payne
# Added RPM for Erik McCree
# Added RPM for Reggie Hearn
# Added RPM for Lauri Markkanen
# Added RPM for Xavier Silas
# Added RPM for Brandon Ingram
# Added RPM for Jarrett Allen
# Added RPM for Dwyane Wade
# Added RPM for Dwyane Wade
# Added RPM for Michael Kidd-Gilchrist
# Added RPM for Isaiah Whitehead
# Added RPM for Andrew Wiggins
# Added RPM for Ike Anigbogu
# Added RPM for Darrell Arthur
# Added RPM for T.J. McConnell
# Added RPM for Marquese Chriss
# Added RPM for Tyler Lydon
# Added RPM for Jabari Bird
# Added RPM for Tim Quarterman
# Added RPM for Sindarius Thornwell
# Added RPM for Andrew Harrison
# Added RPM for Tony Allen
# Added RPM for Jeremy Evans
# Added RPM for Jeremy Lin
# Added RPM for Marco Belinelli
# Added RPM for Marco Belinelli
# Added RPM for Terrence Ross
# [ATL] Taurean Prince's name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is taureanprince
# 	Found harded coded version from Taurean Prince to Taurean Waller-Prince
# Added RPM for Taurean Waller-Prince
# Added RPM for Bryn Forbes
# Added RPM for Josh Magette
# Added RPM for Damien Wilkins
# Added RPM for Alex Poythress
# Added RPM for Devin Robinson
# Added RPM for Alfonzo McKinnie
# Added RPM for Noah Vonleh
# Added RPM for Noah Vonleh
# Added RPM for Greg Monroe
# Added RPM for Greg Monroe
# Added RPM for Greg Monroe
# Added RPM for Daniel Hamilton
# [MIA] Derrick Jones Jr.'s name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is derrickjonesjr
# 	Converted Derrick Jones Jr. to Derrick Jones
# Added RPM for Derrick Jones
# Added RPM for Derrick Jones
# Added RPM for D.J. Wilson
# Added RPM for Dante Cunningham
# Added RPM for Dante Cunningham
# Added RPM for Dennis Schroder
# Added RPM for Luke Kornet
# Added RPM for Omer Asik
# Added RPM for Omer Asik
# Added RPM for Jordan Clarkson
# Added RPM for Jordan Clarkson
# Added RPM for Bogdan Bogdanovic
# Added RPM for Scotty Hopson
# Added RPM for Myke Henry
# Added RPM for Monte Morris
# Added RPM for Quincy Acy
# Added RPM for Rashad Vaughn
# Added RPM for Rashad Vaughn
# Added RPM for Rashad Vaughn
# Added RPM for Shaun Livingston
# Added RPM for Luis Montero
# Added RPM for Marcus Paige
# Added RPM for Marcus Morris
# Added RPM for Mike Scott
# Added RPM for Chris Boucher
# Added RPM for Harrison Barnes
# Added RPM for Dorian Finney-Smith
# Added RPM for PJ Dozier
# Added RPM for Garrett Temple
# Added RPM for Ryan Arcidiacono
# Added RPM for Isaiah Taylor
# Added RPM for C.J. Williams
# Added RPM for Damyean Dotson
# Added RPM for Edmond Sumner
# Added RPM for Troy Williams
# Added RPM for Troy Williams
# Added RPM for Mario Hezonja
# Added RPM for Chandler Parsons
# Added RPM for Tony Snell
# Added RPM for Sterling Brown
# Added RPM for Elfrid Payton
# Added RPM for Elfrid Payton
# Added RPM for Treveon Graham
# Added RPM for Caris LeVert
# Added RPM for Jonathan Isaac
# Added RPM for Justin Anderson
# Added RPM for Ben Moore
# Added RPM for Kadeem Allen
# Added RPM for Robin Lopez
# Added RPM for Jae Crowder
# Added RPM for Jae Crowder
# Added RPM for Quinn Cook
# [CHO] Johnny O'Bryant III's name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is johnnyobryantiii
# 	Found harded coded version from Johnny O'Bryant III to Johnny O'Bryant
# Added RPM for Johnny O'Bryant
# Added RPM for Alex Caruso
# Added RPM for James Young
# Added RPM for Markelle Fultz
# Added RPM for Aaron Jackson
# Added RPM for Ramon Sessions
# Added RPM for Ramon Sessions
# Added RPM for Doug McDermott
# Added RPM for Doug McDermott
# Added RPM for Bruno Caboclo
# Added RPM for Bruno Caboclo
# [DET] James Ennis III's name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is jamesennisiii
# 	Found harded coded version from James Ennis III to James Ennis
# Added RPM for James Ennis
# Added RPM for James Ennis
# Added RPM for Richard Jefferson
# Added RPM for Markel Brown
# Added RPM for Darrun Hilliard
# Added RPM for Dwight Buycks
# [MIA] Derrick Walton Jr.'s name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is derrickwaltonjr
# 	Converted Derrick Walton Jr. to Derrick Walton
# Added RPM for Derrick Walton
# Added RPM for JR Smith
# Added RPM for Walt Lemon Jr.
# Added RPM for Juan Hernangomez
# Added RPM for Xavier Munford
# Added RPM for Charles Cooke
# Added RPM for Alec Burks
# Added RPM for Marquis Teague
# Added RPM for Chris McCullough
# Added RPM for T.J. Warren
# Added RPM for D'Angelo Russell
# Added RPM for Brandon Paul
# Added RPM for Marcus Georges-Hunt
# Added RPM for Nick Young
# Added RPM for Briante Weber
# Added RPM for Briante Weber
# Added RPM for Wayne Selden
# Added RPM for Solomon Hill
# Added RPM for Tyrone Wallace
# Added RPM for Henry Ellenson
# Added RPM for Milton Doyle
# Added RPM for Cheick Diallo
# Added RPM for Malcolm Delaney
# Added RPM for Wesley Matthews
# [SAC] Frank Mason III's name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is frankmasoniii
# 	Found harded coded version from Frank Mason III to Frank Mason
# Added RPM for Frank Mason
# Added RPM for Jordan Mickey
# Added RPM for Georgios Papagiannis
# Added RPM for Georgios Papagiannis
# Added RPM for Frank Ntilikina
# Added RPM for Demetrius Jackson
# Added RPM for Demetrius Jackson
# Added RPM for Avery Bradley
# Added RPM for Avery Bradley
# Added RPM for Isaiah Hicks
# Added RPM for Ivan Rabb
# Added RPM for Jake Layman
# Added RPM for Zach Randolph
# Added RPM for Jamel Artis
# Added RPM for Matthew Dellavedova
# Added RPM for Tarik Black
# Added RPM for Jalen Jones
# Added RPM for Jalen Jones
# Added RPM for Timothe Luwawu-Cabarrot
# Added RPM for Lance Thomas
# Added RPM for London Perrantes
# Added RPM for Jabari Parker
# Added RPM for Deyonta Davis
# Added RPM for Jodie Meeks
# Added RPM for David Nwaba
# Added RPM for Nik Stauskas
# Added RPM for Nik Stauskas
# Added RPM for Antonio Blakeney
# Added RPM for Jaylen Morris
# Added RPM for Bobby Brown
# Added RPM for DeAndre Liggins
# Added RPM for DeAndre Liggins
# Added RPM for Xavier Rathan-Mayes
# Added RPM for Jarell Martin
# Added RPM for Joffrey Lauvergne
# Added RPM for Tyler Ulis
# Added RPM for Torrey Craig
# Added RPM for Justin Jackson
# Added RPM for Brandon Jennings
# Added RPM for Dion Waiters
# [DAL] Dennis Smith Jr.'s name doesn't match bball-ref name. Attempting to resolve...
# 	stubname is dennissmithjr
# 	Converted Dennis Smith Jr. to Dennis Smith
# Added RPM for Dennis Smith
# Added RPM for Jonathon Simmons
# Added RPM for Furkan Korkmaz
# Added RPM for Gorgui Dieng
# Added RPM for Jawun Evans
# Added RPM for DeAndre' Bembry
# Added RPM for Evan Turner
# Added RPM for JaMychal Green
# Added RPM for Skal Labissiere
# Added RPM for John Holland
# Added RPM for Malik Beasley
# Added RPM for Zach LaVine
# Added RPM for Sean Kilpatrick
# Added RPM for Sean Kilpatrick
# Added RPM for Sean Kilpatrick
# Added RPM for Sean Kilpatrick
# Added RPM for Josh Huestis
# Added RPM for Lance Stephenson
# Added RPM for Corey Brewer
# Added RPM for Corey Brewer
# Added RPM for Aaron Brooks
# Added RPM for Jahlil Okafor
# Added RPM for Jahlil Okafor
# Added RPM for Jason Smith
# Added RPM for Thon Maker
# Added RPM for Josh Gray
# Added RPM for Derrick Rose
# Added RPM for Derrick Rose
# Added RPM for Zhou Qi
# Added RPM for Malachi Richardson
# Added RPM for Malachi Richardson
# Added RPM for Tony Parker
# Added RPM for Ian Clark
# Added RPM for Wesley Iwundu
# Added RPM for Dragan Bender
# Added RPM for Zach Collins
# Added RPM for Joe Young
# Added RPM for Norman Powell
# Added RPM for Quincy Pondexter
# Added RPM for Dwayne Bacon
# Added RPM for Tristan Thompson
# Added RPM for Miles Plumlee
# Added RPM for Josh Jackson
# Added RPM for Kay Felder
# Added RPM for Kay Felder
# Added RPM for Joe Johnson
# Added RPM for Joe Johnson
# Added RPM for Shabazz Muhammad
# Added RPM for Shabazz Muhammad
# Added RPM for T.J. Leaf
# Added RPM for Davon Reed
# Added RPM for Isaiah Thomas
# Added RPM for Isaiah Thomas
# Added RPM for Rodney Hood
# Added RPM for Rodney Hood
# Added RPM for De'Aaron Fox
# Added RPM for Terrance Ferguson
# Added RPM for Arron Afflalo
# Added RPM for Ben McLemore
# Added RPM for Rodney Purvis
# Added RPM for Jerryd Bayless
# Added RPM for Tyler Dorsey
# Added RPM for Troy Daniels
# Added RPM for Bismack Biyombo
# Added RPM for Cristiano Felicio
# Added RPM for Jameer Nelson
# Added RPM for Jameer Nelson
# Added RPM for Abdel Nader
# Added RPM for Paul Zipser
# Added RPM for Jamal Crawford
# Added RPM for Patrick McCaw
# Added RPM for Malik Monk
# Added RPM for Semi Ojeleye
# Added RPM for Emmanuel Mudiay
# Added RPM for Emmanuel Mudiay
# Added RPM for Kobi Simmons

# %% [markdown]
# ## 3. Process Play-by-Play Data
#
# Here we convert the raw play-by-play data from nba.com to a version with lineup infomation, which we need to do the RAPM calculation. More precisely, we parse the play-by-play data into this form:
#
# ```json
# [ {
#     "home_lineup": [playerid1, ..., playerid5],
#     "away_lineup": [playerid6, ..., playerid10],
#     "score_margin_update": 2, #(0-4 range of points that can be scored on a possession, not accounting for weirdness that can happen with technicals, flagrants)
#     "home_team_is_on_offense": True, # or false,
#     "possession_metadata": 3 #any data we want to keep about what the event was, at least event number for reference
#    }, {...}, ...
# ]
# ```
# Each object in the list is denotes a possession ending, either a turnover, made shot, defensive rebound, or the last of a series of free throws.
#
# We store this in a collection called possessions.[season] for each season

# %%
# get back into main rapm-model directory
# only run this once, or just put in an absolute path e.g. /home/dev/rapm-model
os.chdir("..")

# %%
import parse_pbp
import importlib
import common_utils
#importlib.reload(parse_pbp)
#importlib.reload(common_utils)

year = 2018
parse_pbp.save_lineup_data_for_season(year, "playoffs")
# Out:
# creating index
# index created (or already existed)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-9a909cb7a262> in <module>()
#       6
#       7 year = 2018
# ----> 8 parse_pbp.save_lineup_data_for_season(year, "playoffs")
#
# /home/aidan/rapm-model/parse_pbp.py in save_lineup_data_for_season(year, season_type)
#     272     games = db.games[season_type][year_string].find()
#     273     num_games = games.count()
# --> 274     prev_time = time.perf_counter()
#     275     for index, game in enumerate(games):
#     276         #if game["game_index"]:
#
# AttributeError: 'module' object has no attribute 'perf_counter'

# %% [markdown]
# ## 4. Convert Play-by-Play/Possession Data into Matrix
#
# We convert the possessions to matrix as described in [this talk by Jeremias Engelmann](https://www.youtube.com/watch?v=OuC0YZTADcE) and summarized in the accompanying paper. These matrices were too big for the MongoDB database and are stored as python pickles.

# %%
import calculate_rapm
import importlib

#importlib.reload(calculate_rapm)

# Creates a seasons table in MongoDB where each row is an NBA season with the following attributes:
# {"year_string", "games_data"}
# "games_data" is an object where the keys are the game_ids and the information stored is the home and away team for that game
#     This is totally redundant with the games collection, but stored in a way for faster lookups
calculate_rapm.store_games_data(year, "playoffs")

# This does a pass through the possessions collection and calculates possession count for each player
# It updates the "seasons" collection with an additional "player_info" attribute
# which is an object where the keys are the player name and team and the data associated with it a numerical index, a possession count, and a player stub name
# It also updates the players table with the possession counts
calculate_rapm.store_player_and_possession_data_for_matrix(year, "playoffs")

# This does a pass through the possessions data and creates the player/possession matrix for calculating RAPM
X, Y = calculate_rapm.build_matrix(year, "playoffs")
# Out:
# storing games data...
# stored games data
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-aa98ecff60f8> in <module>()
#      14 # which is an object where the keys are the player name and team and the data associated with it a numerical index, a possession count, and a player stub name
#      15 # It also updates the players table with the possession counts
# ---> 16 calculate_rapm.store_player_and_possession_data_for_matrix(year, "playoffs")
#      17
#      18 # This does a pass through the possessions data and creates the player/possession matrix for calculating RAPM
#
# /home/aidan/rapm-model/calculate_rapm.py in store_player_and_possession_data_for_matrix(year, season_type)
#     109     # player info should already be calculated, this is to get index
#     110     if season_type == "playoffs":
# --> 111         num_players = len(db.seasons.find_one({ "year_string": year_string })["player_info"])
#     112
#     113     for possession in possessions:
#
# KeyError: 'player_info'

# %% [markdown]
# ## 5. Run Regression Model w/ Matrix

# %%
import pickle

import calculate_rapm
from common_utils import construct_year_string
year = 2018
year_string = construct_year_string(year)
X = pickle.load(open("matrices/{}-X-playoffs.indicator.pickle".format(year_string), "rb"))
Y = pickle.load(open("matrices/{}-Y-playoffs.pickle".format(year_string), "rb"))
# The above steps should only need to be done once so long as no new games are added
# This step runs the model, stores the values to the players table and prints out the top 50 in ORAPM
calculate_rapm.calculate_rapm(year, X, Y, season_type="playoffs")

# RAPMs are calculated for each "player-team" pair
# For traded players, this calculates a weighted average for their whole season
calculate_rapm.deal_with_traded_players(year)

# %%
import json

from pymongo import MongoClient

import mongo_config

client = MongoClient(mongo_config.host, mongo_config.port)
db = client.nba

players = db.players.find(
    filter = {
        "player_index.season": 2018
    },
    projection= {
        "player": 1,
        "team_id": 1,
        "orapm_playoffs": 1,
        "drapm_playoffs": 1,
        "rapm_playoffs": 1,
        "playoffs_possessions": 1
    }, 
    sort= [("rapm_playoffs", -1)]
)
result = []
index = 1
for player in players:
    if "playoffs_possessions" in player:
        result.append([
            index,
            player["player"],
            player["team_id"],
            player["playoffs_possessions"],
            round(player["orapm_playoffs"], 4),
            round(player["drapm_playoffs"], 4),
            round(player["rapm_playoffs"], 4)
        ])
        index += 1
#print(result)
with open("2017-18-playoffs-rapm.json", "w") as jsonfile:
    json.dump({
        "data": result
    }, jsonfile)
