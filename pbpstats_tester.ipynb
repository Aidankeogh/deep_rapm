# %%
from pbpstats.stats_game_data import StatsGameData

game_data = StatsGameData('0041800406')
game_data.get_game_data()

# %%
game_data.get_game_data(ignore_rebound_and_shot_order=True)

# %%
player_stats = game_data.get_aggregated_possession_stats_for_entity_type('player')

# %%
lineup_opponent_stats = game_data.get_aggregated_possession_stats_for_entity_type('lineupopponent')
lineup_opponent_stats
# Out:
# {'1610612744': defaultdict(<function pbpstats.game_data.GameData.get_aggregated_possession_stats_for_entity_type.<locals>.<lambda>()>,
#              {'1626172-201939-202691-203110-2738': defaultdict(int,
#                           {'SecondsPlayedOff': 492.0,
#                            'Period1Fouls0SecondsPlayedOff': 558.0,
#                            'SecondChanceSecondsPlayedOff': 70.0,
#                            'ShortMidRangeBlockedOffReboundOpportunities': 3.0,
#                            'OnFloorOffReb': 15,
#                            'PlusMinus': -1.0,
#                            'OffPoss': 31.0,
#                            'SecondChanceOffPoss': 3.0,
#                            'ShortMidRangeBlockedOffRebounds': 1,
#                            'UnassistedAtRim': 2,
#                            'Total2ptShotDistance': 178.0,
#                            'Total2ptShotsWithDistance': 18,
#                            'SecondChanceUnassistedAtRim': 1,
#                            'ShortMidRangeBlocked': 3,
#                            'ShortMidRangeBlockedOffRebounded': 1,
#                            'ShortMidRangeBlockedOffReboundedOpportunities': 3,
#                            'SecondsPlayedDef': 444.0,
#                            'Period1Fouls0SecondsPlayedDef': 534.0,
#                            'DefPoss': 31.0,
#                            'AssistedArc3': 3,
#                            'Total3ptShotDistance': 309.90000000000003,
#                            'Total3ptShotsWithDistance': 12,
#                            'Arc3Assists': 3,
#                            '201980:AssistsTo:200768:Arc3': 1,
#                            'Arc3DefReboundOpportunities': 4.0,
#                            'Arc3DefRebounds': 4,
#                            'UnassistedArc3': 2,
#                            'Personal Fouls': 3,
#                            'Period1Fouls1SecondsPlayedDef': 183.0,
#                            'Steals': 2,
#                            'Period1Fouls1SecondsPlayedOff': 272.0,
#                            'Arc3OffReboundOpportunities': 4.0,
#                            'MissedArc3': 4,
#                            'Arc3OffReboundedOpportunities': 4,
#                            'OpponentPoints': 41.0,
#                            'SecondChanceSecondsPlayedDef': 145.0,
#                            'ShortMidRangeDefReboundOpportunities': 3.0,
#                            'FTDefReboundOpportunities': 3.0,
#                            'SecondChanceDefPoss': 5.0,
#                            'Shooting Fouls': 5,
#                            'FTDefRebounds': 3,
#                            'DeadBallTurnovers': 1,
#                            'BadPassOutOfBoundsTurnovers': 1,
#                            'DefensiveGoaltends': 1,
#                            'AssistedCorner3': 1,
#                            'Corner3Assists': 1,
#                            '200768:AssistsTo:1627783:Corner3': 1,
#                            '202695:AssistsTo:1627783:Arc3': 1,
#                            'Corner3DefReboundOpportunities': 1.0,
#                            'Corner3DefRebounds': 1,
#                            'MissedShortMidRange': 3,
#                            'ShortMidRangeOffReboundOpportunities': 3.0,
#                            'ShortMidRangeOffReboundedOpportunities': 3,
#                            'AtRimDefReboundOpportunities': 2.0,
#                            'Personal Fouls Drawn': 4,
#                            'Period1Fouls2SecondsPlayedOff': 5.0,
#                            'LiveBallTurnovers': 2,
#                            'BadPassTurnovers': 2,
#                            'PenaltySecondsPlayedDef': 154.0,
#                            'PenaltyDefPoss': 9.0,
#                            'Period1Fouls2SecondsPlayedDef': 3.0,
#                            'Period2Fouls1SecondsPlayedOff': 204.0,
#                            'LongMidRangeOffReboundOpportunities': 3.0,
#                            'Period2Fouls0SecondsPlayedOff': 80.0,
#                            'Period2Fouls2SecondsPlayedOff': 104.0,
#                            'MissedLongMidRange': 3,
#                            'LongMidRangeOffReboundedOpportunities': 3,
#                            'Period2Fouls1SecondsPlayedDef': 213.0,
#                            'Period2Fouls0SecondsPlayedDef': 100.0,
#                            'Period2Fouls2SecondsPlayedDef': 167.0,
#                            'PenaltySecondsPlayedOff': 162.0,
#                            'PenaltyLongMidRangeOffReboundOpportunities': 1.0,
#                            'PenaltyOffPoss': 11.0,
#                            'PenaltyMissedLongMidRange': 1,
#                            'Loose Ball Fouls': 1,
#                            'UnassistedShortMidRange': 3,
#                            'PenaltyUnassistedShortMidRange': 3,
#                            'PenaltyShortMidRangeDefReboundOpportunities': 2.0,
#                            'LongMidRangeDefReboundOpportunities': 2.0,
#                            'PenaltyLongMidRangeDefReboundOpportunities': 1.0,
#                            'LongMidRangeDefRebounds': 1,
#                            'PenaltyLongMidRangeDefRebounds': 1,
#                            'ShortMidRangeAssists': 3,
#                            'PenaltyShortMidRangeAssists': 2,
#                            '1627783:AssistsTo:202695:ShortMidRange': 1,
#                            'Penalty1627783:AssistsTo:202695:ShortMidRange': 1,
#                            'Shooting Fouls Drawn': 3,
#                            'PenaltyShooting Fouls Drawn': 1,
#                            'AssistedShortMidRange': 3,
#                            'PenaltyAssistedShortMidRange': 2,
#                            '2pt And 1 Free Throw Trips': 2,
#                            'Penalty2pt And 1 Free Throw Trips': 1,
#                            'FtsMade': 4,
#                            'PenaltyFtsMade': 1,
#                            'PenaltyShooting Fouls': 1,
#                            'Period2Fouls3SecondsPlayedOff': 12.0,
#                            'Period2Fouls3SecondsPlayedDef': 20.0,
#                            'PenaltyArc3OffReboundOpportunities': 2.0,
#                            'PenaltyMissedArc3': 2,
#                            'Period3Fouls1SecondsPlayedDef': 300.0,
#                            'Period3Fouls0SecondsPlayedDef': 165.0,
#                            'Period3Fouls2SecondsPlayedDef': 165.0,
#                            'Period3Fouls3SecondsPlayedDef': 370.0,
#                            'Period3Fouls1SecondsPlayedOff': 355.0,
#                            'Period3Fouls0SecondsPlayedOff': 208.0,
#                            'AssistedLongMidRange': 1,
#                            'Period3Fouls2SecondsPlayedOff': 171.0,
#                            'LongMidRangeAssists': 1,
#                            '201188:AssistsTo:1627832:LongMidRange': 1,
#                            'Period3Fouls3SecondsPlayedOff': 491.0,
#                            '200768:AssistsTo:1627783:ShortMidRange': 1,
#                            'ShortMidRangeOffRebounded': 2,
#                            'ShortMidRangeOffRebounds': 2,
#                            'SecondChanceArc3Assists': 1,
#                            '201188:AssistsTo:202695:Arc3': 1,
#                            'SecondChance201188:AssistsTo:202695:Arc3': 1,
#                            'SecondChanceAssistedArc3': 1,
#                            '2pt Shooting Foul Free Throw Trips': 1,
#                            'Corner3OffReboundOpportunities': 2.0,
#                            'PenaltyCorner3OffReboundOpportunities': 2.0,
#                            'MissedCorner3': 2,
#                            'PenaltyMissedCorner3': 2,
#                            'Corner3OffReboundedOpportunities': 2,
#                            'PenaltyShortMidRangeOffRebounds': 1,
#                            'PenaltyShortMidRangeOffReboundOpportunities': 1.0,
#                            'PenaltyOnFloorOffReb': 5,
#                            'PenaltyMissedShortMidRange': 1,
#                            'SecondChanceMissedCorner3': 1,
#                            '201980:AssistsTo:1627783:ShortMidRange': 1,
#                            'Penalty201980:AssistsTo:1627783:ShortMidRange': 1,
#                            'PenaltySteals': 1,
#                            'PenaltyLiveBallTurnovers': 1,
#                            'PenaltyBadPassTurnovers': 1}),
#               '101106-201939-202691-203110-2738': defaultdict(int,
#                           {'SecondsPlayedOff': 40.0,
#                            'Period1Fouls1SecondsPlayedOff': 120.0,
#                            'ShortMidRangeOffReboundOpportunities': 1.0,
#                            'OffPoss': 2.0,
#                            'MissedShortMidRange': 1,
#                            'Total2ptShotDistance': 9.6,
#                            'Total2ptShotsWithDistance': 2,
#                            'ShortMidRangeOffReboundedOpportunities': 1,
#                            'Period1Fouls0SecondsPlayedOff': 80.0,
#                            'SecondsPlayedDef': 25.0,
#                            'Period1Fouls1SecondsPlayedDef': 75.0,
#                            'DefPoss': 2.0,
#                            'Period1Fouls0SecondsPlayedDef': 50.0,
#                            'Steals': 1,
#                            'AssistedAtRim': 1,
#                            'PlusMinus': -1.0,
#                            'AtRimAssists': 1,
#                            '200768:AssistsTo:1627783:AtRim': 1,
#                            'OpponentPoints': 3.0}),
#               '101106-1628035-201939-202691-203110': defaultdict(int,
#                           {'SecondsPlayedOff': 51.0,
#                            'Period1Fouls1SecondsPlayedOff': 153.0,
#                            'PlusMinus': 2.0,
#                            'OffPoss': 5.0,
#                            'Period1Fouls0SecondsPlayedOff': 102.0,
#                            'UnassistedAtRim': 1,
#                            'Total2ptShotDistance': 2.2,
#                            'Total2ptShotsWithDistance': 1,
#                            'SecondsPlayedDef': 54.0,
#                            'Period1Fouls1SecondsPlayedDef': 162.0,
#                            'ShortMidRangeDefReboundOpportunities': 1.0,
#                            'DefPoss': 4.0,
#                            'ShortMidRangeDefRebounds': 1,
#                            'Period1Fouls0SecondsPlayedDef': 108.0,
#                            'Shooting Fouls Drawn': 2,
#                            '2pt Shooting Foul Free Throw Trips': 2,
#                            'FtsMade': 2,
#                            'FTOffReboundOpportunities': 1.0,
#                            'FTOffReboundedOpportunities': 1,
#                            'OpponentPoints': 5.0,
#                            'Arc3OffReboundOpportunities': 1.0,
#                            'MissedArc3': 1,
#                            'Total3ptShotDistance': 48.0,
#                            'Total3ptShotsWithDistance': 2,
#                            'Arc3OffReboundedOpportunities': 1,
#                            'AssistedCorner3': 1,
#                            'Corner3Assists': 1,
#                            '201188:AssistsTo:1627832:Corner3': 1,
#                            'Steals': 1}),
#               '1628035-201939-202326-202691-203110': defaultdict(int,
#                           {'SecondsPlayedDef': 104.0,
#                            'Period1Fouls1SecondsPlayedDef': 119.0,
#                            'SecondChanceSecondsPlayedDef': 15.0,
#                            'AtRimDefReboundOpportunities': 1.0,
#                            'Arc3DefRebounds': 1,
#                            'Arc3DefReboundOpportunities': 1.0,
#                            'DefPoss': 9.0,
#                            'SecondChanceDefPoss': 1.0,
#                            'Period1Fouls0SecondsPlayedDef': 196.0,
#                            'SecondsPlayedOff': 169.0,
#                            'Period1Fouls1SecondsPlayedOff': 133.0,
#                            'Arc3OffReboundOpportunities': 3.0,
#                            'OffPoss': 9.0,
#                            'Period1Fouls0SecondsPlayedOff': 237.0,
#                            'MissedArc3': 3,
#                            'Total3ptShotDistance': 99.8,
#                            'Total3ptShotsWithDistance': 4,
#                            'Arc3OffReboundedOpportunities': 3,
#                            'PlusMinus': -8.0,
#                            'OpponentPoints': 14.0,
#                            'Shooting Fouls': 2,
#                            'DeadBallTurnovers': 1,
#                            'Travels': 1,
#                            'PenaltySecondsPlayedDef': 64.0,
#                            'PenaltyDefPoss': 6.0,
#                            'Corner3OffReboundOpportunities': 1.0,
#                            'MissedCorner3': 1,
#                            'Corner3OffReboundedOpportunities': 1,
#                            'Offensive Fouls Drawn': 1,
#                            'PenaltyOffensive Fouls Drawn': 1,
#                            'Period3Fouls1SecondsPlayedOff': 265.0,
#                            'PenaltySecondsPlayedOff': 95.0,
#                            'PenaltyArc3OffReboundOpportunities': 1.0,
#                            'PenaltyOffPoss': 5.0,
#                            'PenaltyMissedArc3': 1,
#                            'Period3Fouls0SecondsPlayedOff': 92.0,
#                            'Period3Fouls3SecondsPlayedOff': 72.0,
#                            'Period3Fouls1SecondsPlayedDef': 113.0,
#                            'Period3Fouls0SecondsPlayedDef': 41.0,
#                            'Period3Fouls3SecondsPlayedDef': 37.0,
#                            'AtRimAssists': 1,
#                            'PenaltyAtRimAssists': 1,
#                            '201586:AssistsTo:202695:AtRim': 1,
#                            'Penalty201586:AssistsTo:202695:AtRim': 1,
#                            'Shooting Fouls Drawn': 2,
#                            'PenaltyShooting Fouls Drawn': 2,
#                            'AssistedAtRim': 1,
#                            'Total2ptShotDistance': 2.4,
#                            'Total2ptShotsWithDistance': 1,
#                            'PenaltyAssistedAtRim': 1,
#                            '2pt And 1 Free Throw Trips': 1,
#                            'Penalty2pt And 1 Free Throw Trips': 1,
#                            'FtsMade': 4,
#                            'PenaltyFtsMade': 4,
#                            '2pt Shooting Foul Free Throw Trips': 1,
#                            'Penalty2pt Shooting Foul Free Throw Trips': 1,
#                            'FTDefRebounds': 1,
#                            'PenaltyFTDefRebounds': 1,
#                            'FTDefReboundOpportunities': 1.0,
#                            'PenaltyFTDefReboundOpportunities': 1.0,
#                            'Period3Fouls4SecondsPlayedDef': 14.0,
#                            'Personal Fouls': 1,
#                            'PenaltyPersonal Fouls': 1,
#                            'Period3Fouls4SecondsPlayedOff': 46.0,
#                            'LiveBallTurnovers': 1,
#                            'PenaltyLiveBallTurnovers': 1,
#                            'LostBallTurnovers': 1,
#                            'PenaltyLostBallTurnovers': 1,
#                            'PenaltyShooting Fouls': 1,
#                            'Personal Take Fouls Drawn': 1,
#                            'PenaltyPersonal Take Fouls Drawn': 1,
#                            'Penalty Free Throw Trips': 1,
#                            'PenaltyPenalty Free Throw Trips': 1}),
#               '1626188-201939-202326-203110-2738': defaultdict(int,
#                           {'SecondsPlayedOff': 104.0,
#                            'Period1Fouls0SecondsPlayedOff': 162.0,
#                            'PlusMinus': 5.0,
#                            'OffPoss': 10.0,
#                            'Period1Fouls1SecondsPlayedOff': 108.0,
#                            'AssistedCorner3': 1,
#                            'Total3ptShotDistance': 102.10000000000001,
#                            'Total3ptShotsWithDistance': 4,
#                            'Corner3Assists': 1,
#                            '202695:AssistsTo:200768:Corner3': 1,
#                            'SecondsPlayedDef': 144.0,
#                            'Period1Fouls0SecondsPlayedDef': 144.0,
#                            'PenaltySecondsPlayedDef': 136.0,
#                            'OpponentPoints': 9.0,
#                            'DefPoss': 8.0,
#                            'PenaltyDefPoss': 8.0,
#                            'Period1Fouls1SecondsPlayedDef': 96.0,
#                            'ShortMidRangeAssists': 1,
#                            '200768:AssistsTo:201586:ShortMidRange': 1,
#                            'AssistedShortMidRange': 1,
#                            'Total2ptShotDistance': 44.5,
#                            'Total2ptShotsWithDistance': 5,
#                            'Arc3DefRebounds': 2,
#                            'PenaltyArc3DefRebounds': 2,
#                            'Arc3DefReboundOpportunities': 4.0,
#                            'PenaltyArc3DefReboundOpportunities': 4.0,
#                            'Arc3OffReboundOpportunities': 3.0,
#                            'MissedArc3': 3,
#                            'Arc3OffReboundedOpportunities': 3,
#                            'ShortMidRangeBlockedDefReboundOpportunities': 1.0,
#                            'PenaltyShortMidRangeBlockedDefReboundOpportunities': 1.0,
#                            'BlockedShortMidRange': 1,
#                            'BlockedShortMidRangeRecovered': 1,
#                            'ShortMidRangeBlockedDefRebounds': 1,
#                            'PenaltyShortMidRangeBlockedDefRebounds': 1,
#                            'UnassistedLongMidRange': 1,
#                            'Shooting Fouls': 1,
#                            'PenaltyShooting Fouls': 1,
#                            'Period3Fouls1SecondsPlayedOff': 78.0,
#                            'PenaltySecondsPlayedOff': 26.0,
#                            'FTOffReboundOpportunities': 1.0,
#                            'PenaltyFTOffReboundOpportunities': 1.0,
#                            'PenaltyOffPoss': 5.0,
#                            'Period3Fouls4SecondsPlayedOff': 52.0,
#                            'FTOffReboundedOpportunities': 1,
#                            'Period3Fouls1SecondsPlayedDef': 195.0,
#                            'Period3Fouls4SecondsPlayedDef': 130.0,
#                            'Shooting Fouls Drawn': 1,
#                            'PenaltyShooting Fouls Drawn': 1,
#                            '2pt Shooting Foul Free Throw Trips': 1,
#                            'Penalty2pt Shooting Foul Free Throw Trips': 1,
#                            'FtsMade': 3,
#                            'PenaltyFtsMade': 3,
#                            'AssistedAtRim': 1,
#                            'PenaltyAssistedAtRim': 1,
#                            'AtRimAssists': 1,
#                            'PenaltyAtRimAssists': 1,
#                            '202695:AssistsTo:200768:AtRim': 1,
#                            'Penalty202695:AssistsTo:200768:AtRim': 1,
#                            'SecondChanceSecondsPlayedDef': 40.0,
#                            'SecondChanceDefPoss': 1.0,
#                            'Steals': 1,
#                            'SecondChanceSteals': 1,
#                            'PenaltySteals': 1,
#                            'PenaltyMissedArc3': 1,
#                            'SecondChanceSecondsPlayedOff': 30.0,
#                            'PenaltyArc3OffReboundOpportunities': 1.0,
#                            'OnFloorOffReb': 15,
#                            'PenaltyOnFloorOffReb': 10,
#                            'Arc3OffRebounded': 2,
#                            'ShortMidRangeOffReboundOpportunities': 1.0,
#                            'PenaltyShortMidRangeOffReboundOpportunities': 1.0,
#                            'SecondChanceOffPoss': 2.0,
#                            'Arc3OffRebounds': 2,
#                            'PenaltyArc3OffRebounds': 1,
#                            'MissedShortMidRange': 1,
#                            'SecondChanceMissedShortMidRange': 1,
#                            'PenaltyMissedShortMidRange': 1,
#                            'ShortMidRangeOffRebounded': 1,
#                            'ShortMidRangeOffReboundedOpportunities': 1,
#                            'ShortMidRangeOffRebounds': 1,
#                            'PenaltyShortMidRangeOffRebounds': 1,
#                            'Period4Fouls1SecondsPlayedDef': 62.0,
#                            'Period4Fouls4SecondsPlayedDef': 62.0,
#                            'Period4Fouls2SecondsPlayedDef': 8.0,
#                            'Personal Fouls': 1,
#                            'Period4Fouls3SecondsPlayedDef': 23.0,
#                            'Period4Fouls1SecondsPlayedOff': 48.0,
#                            'Period4Fouls4SecondsPlayedOff': 48.0,
#                            'Period4Fouls3SecondsPlayedOff': 24.0,
#                            'UnassistedShortMidRange': 1,
#                            'SecondChanceUnassistedShortMidRange': 1,
#                            'Loose Ball Fouls': 1,
#                            'PenaltyLoose Ball Fouls': 1,
#                            'Personal Fouls Drawn': 1,
#                            'PenaltyPersonal Fouls Drawn': 1,
#                            'Penalty Free Throw Trips': 1,
#                            'PenaltyPenalty Free Throw Trips': 1}),
#               '1626172-1626188-202326-202691-2733': defaultdict(int,
#                           {'SecondsPlayedDef': 134.0,
#                            'Period2Fouls0SecondsPlayedDef': 262.0,
#                            'AtRimDefReboundOpportunities': 1.0,
#                            'DefPoss': 8.0,
#                            'Period2Fouls1SecondsPlayedDef': 274.0,
#                            'Period2Fouls2SecondsPlayedDef': 134.0,
#                            'AtRimDefRebounds': 1,
#                            'SecondsPlayedOff': 94.0,
#                            'Period2Fouls0SecondsPlayedOff': 164.0,
#                            'SecondChanceSecondsPlayedOff': 0.0,
#                            'ShortMidRangeBlockedOffReboundOpportunities': 2.0,
#                            'OnFloorOffReb': 5,
#                            'PlusMinus': 4.0,
#                            'OffPoss': 8.0,
#                            'SecondChanceOffPoss': 1.0,
#                            'Period2Fouls1SecondsPlayedOff': 212.0,
#                            'Period2Fouls2SecondsPlayedOff': 94.0,
#                            'Shooting Fouls Drawn': 1,
#                            'ShortMidRangeBlockedOffRebounds': 1,
#                            '2pt Shooting Foul Free Throw Trips': 1,
#                            'SecondChance2pt Shooting Foul Free Throw Trips': 1,
#                            'FtsMade': 2,
#                            'SecondChanceFtsMade': 2,
#                            'ShortMidRangeBlocked': 2,
#                            'Total2ptShotDistance': 30.699999999999996,
#                            'Total2ptShotsWithDistance': 5,
#                            'ShortMidRangeBlockedOffRebounded': 1,
#                            'ShortMidRangeBlockedOffReboundedOpportunities': 2,
#                            'OpponentPoints': 6.0,
#                            'LiveBallTurnovers': 1,
#                            'BadPassTurnovers': 1,
#                            'Steals': 1,
#                            'AtRimOffReboundOpportunities': 1.0,
#                            'MissedAtRim': 1,
#                            'AtRimOffReboundedOpportunities': 1,
#                            'ShortMidRangeOffReboundOpportunities': 1.0,
#                            'MissedShortMidRange': 1,
#                            'ShortMidRangeOffReboundedOpportunities': 1,
#                            'Loose Ball Fouls': 1,
#                            'Shooting Fouls': 1,
#                            'LongMidRangeDefReboundOpportunities': 1.0,
#                            'LongMidRangeDefRebounds': 1,
#                            'ShortMidRangeAssists': 1,
#                            '200768:AssistsTo:201586:ShortMidRange': 1,
#                            'AssistedShortMidRange': 1,
#                            'AssistedCorner3': 1,
#                            'Total3ptShotDistance': 49.0,
#                            'Total3ptShotsWithDistance': 2,
#                            'Corner3Assists': 1,
#                            '201586:AssistsTo:1627783:Corner3': 1,
#                            'ShortMidRangeDefReboundOpportunities': 1.0,
#                            'ShortMidRangeDefRebounds': 1,
#                            'AssistedArc3': 1,
#                            'Arc3Assists': 1,
#                            '200768:AssistsTo:1627832:Arc3': 1}),
#               '1626172-201939-202691-203110-2733': defaultdict(int,
#                           {'SecondsPlayedDef': 45.0,
#                            'Period2Fouls1SecondsPlayedDef': 135.0,
#                            'ShortMidRangeDefReboundOpportunities': 2.0,
#                            'DefPoss': 3.0,
#                            'Period2Fouls0SecondsPlayedDef': 45.0,
#                            'Period2Fouls2SecondsPlayedDef': 45.0,
#                            'ShortMidRangeDefRebounds': 2,
#                            'SecondsPlayedOff': 64.0,
#                            'Period2Fouls1SecondsPlayedOff': 192.0,
#                            'SecondChanceSecondsPlayedOff': 30.0,
#                            'ShortMidRangeOffReboundOpportunities': 2.0,
#                            'OnFloorOffReb': 5,
#                            'MissedArc3': 1,
#                            'Total3ptShotDistance': 25.4,
#                            'Total3ptShotsWithDistance': 1,
#                            'SecondChanceMissedArc3': 1,
#                            'Arc3OffReboundOpportunities': 1.0,
#                            'Arc3OffReboundedOpportunities': 1,
#                            'OffPoss': 2.0,
#                            'SecondChanceOffPoss': 1.0,
#                            'Period2Fouls0SecondsPlayedOff': 64.0,
#                            'MissedShortMidRange': 2,
#                            'Total2ptShotDistance': 22.6,
#                            'Total2ptShotsWithDistance': 2,
#                            'ShortMidRangeOffRebounds': 1,
#                            'ShortMidRangeOffRebounded': 1,
#                            'ShortMidRangeOffReboundedOpportunities': 2,
#                            'Period2Fouls2SecondsPlayedOff': 64.0,
#                            'PlusMinus': -2.0,
#                            'OpponentPoints': 2.0,
#                            'Personal Fouls Drawn': 1}),
#               '1628035-201939-202691-203110-2738': defaultdict(int,
#                           {'SecondsPlayedOff': 98.0,
#                            'Period2Fouls1SecondsPlayedOff': 294.0,
#                            'OffPoss': 7.0,
#                            'Period2Fouls0SecondsPlayedOff': 98.0,
#                            'Period2Fouls2SecondsPlayedOff': 98.0,
#                            'LiveBallTurnovers': 2,
#                            'BadPassTurnovers': 2,
#                            'SecondsPlayedDef': 105.0,
#                            'Period2Fouls1SecondsPlayedDef': 315.0,
#                            'PlusMinus': 1.0,
#                            'OpponentPoints': 9.0,
#                            'DefPoss': 7.0,
#                            'Period2Fouls0SecondsPlayedDef': 105.0,
#                            'Period2Fouls2SecondsPlayedDef': 105.0,
#                            'Personal Fouls Drawn': 1,
#                            'PenaltySecondsPlayedOff': 71.0,
#                            'LongMidRangeAssists': 1,
#                            'PenaltyLongMidRangeAssists': 1,
#                            '1627783:AssistsTo:202695:LongMidRange': 1,
#                            'Penalty1627783:AssistsTo:202695:LongMidRange': 1,
#                            'PenaltyOffPoss': 5.0,
#                            'AssistedLongMidRange': 1,
#                            'Total2ptShotDistance': 34.599999999999994,
#                            'Total2ptShotsWithDistance': 5,
#                            'PenaltyAssistedLongMidRange': 1,
#                            'AtRimDefReboundOpportunities': 1.0,
#                            'AtRimDefRebounds': 1,
#                            'UnassistedAtRim': 1,
#                            'PenaltyUnassistedAtRim': 1,
#                            'SecondChanceSecondsPlayedDef': 15.0,
#                            'Arc3DefReboundOpportunities': 2.0,
#                            'SecondChanceDefPoss': 1.0,
#                            'Shooting Fouls': 1,
#                            'AssistedShortMidRange': 1,
#                            'PenaltyAssistedShortMidRange': 1,
#                            'ShortMidRangeAssists': 1,
#                            'PenaltyShortMidRangeAssists': 1,
#                            '201980:AssistsTo:201586:ShortMidRange': 1,
#                            'Penalty201980:AssistsTo:201586:ShortMidRange': 1,
#                            'Arc3DefRebounds': 1,
#                            'AtRimAssists': 2,
#                            'PenaltyAtRimAssists': 2,
#                            '1627783:AssistsTo:201586:AtRim': 1,
#                            'Penalty1627783:AssistsTo:201586:AtRim': 1,
#                            'AssistedAtRim': 2,
#                            'PenaltyAssistedAtRim': 2,
#                            '200768:AssistsTo:201586:AtRim': 1,
#                            'Penalty200768:AssistsTo:201586:AtRim': 1}),
#               '1626188-1628035-201939-202326-203110': defaultdict(int,
#                           {'SecondsPlayedDef': 29.0,
#                            'Period3Fouls1SecondsPlayedDef': 87.0,
#                            'PenaltySecondsPlayedDef': 29.0,
#                            'Corner3DefReboundOpportunities': 1.0,
#                            'PenaltyCorner3DefReboundOpportunities': 1.0,
#                            'DefPoss': 2.0,
#                            'PenaltyDefPoss': 2.0,
#                            'Period3Fouls4SecondsPlayedDef': 58.0,
#                            'Corner3DefRebounds': 1,
#                            'PenaltyCorner3DefRebounds': 1,
#                            'SecondsPlayedOff': 19.0,
#                            'Period3Fouls1SecondsPlayedOff': 57.0,
#                            'PenaltySecondsPlayedOff': 19.0,
#                            'MissedShortMidRange': 1,
#                            'Total2ptShotDistance': 7.3,
#                            'Total2ptShotsWithDistance': 1,
#                            'PenaltyMissedShortMidRange': 1,
#                            'ShortMidRangeOffReboundOpportunities': 1.0,
#                            'PenaltyShortMidRangeOffReboundOpportunities': 1.0,
#                            'ShortMidRangeOffReboundedOpportunities': 1,
#                            'OffPoss': 1.0,
#                            'PenaltyOffPoss': 1.0,
#                            'Period3Fouls4SecondsPlayedOff': 38.0,
#                            'ShortMidRangeDefRebounds': 1,
#                            'PenaltyShortMidRangeDefRebounds': 1,
#                            'ShortMidRangeDefReboundOpportunities': 1.0,
#                            'PenaltyShortMidRangeDefReboundOpportunities': 1.0,
#                            'PlusMinus': 1.0,
#                            'Personal Fouls Drawn': 1,
#                            'PenaltyPersonal Fouls Drawn': 1,
#                            'Penalty Free Throw Trips': 1,
#                            'PenaltyPenalty Free Throw Trips': 1,
#                            'FtsMade': 1,
#                            'PenaltyFtsMade': 1}),
#               '1626188-201973-202326-203110-2733': defaultdict(int,
#                           {'SecondsPlayedOff': 67.0,
#                            'Period4Fouls1SecondsPlayedOff': 215.0,
#                            'LongMidRangeOffReboundOpportunities': 2.0,
#                            'OffPoss': 5.0,
#                            'Period4Fouls4SecondsPlayedOff': 67.0,
#                            'MissedLongMidRange': 2,
#                            'Total2ptShotDistance': 44.3,
#                            'Total2ptShotsWithDistance': 4,
#                            'LongMidRangeOffReboundedOpportunities': 2,
#                            'SecondsPlayedDef': 72.0,
#                            'Period4Fouls1SecondsPlayedDef': 211.0,
#                            'SecondChanceSecondsPlayedDef': 0.0,
#                            'AtRimDefReboundOpportunities': 1.0,
#                            'PlusMinus': -1.0,
#                            'OpponentPoints': 3.0,
#                            'DefPoss': 4.0,
#                            'SecondChanceDefPoss': 1.0,
#                            'Period4Fouls4SecondsPlayedDef': 72.0,
#                            'Shooting Fouls': 1,
#                            'LiveBallTurnovers': 1,
#                            'LostBallTurnovers': 1,
#                            'Period4Fouls2SecondsPlayedOff': 40.0,
#                            'Steals': 1,
#                            'Period4Fouls2SecondsPlayedDef': 57.0,
#                            'AtRimAssists': 1,
#                            '200768:AssistsTo:201586:AtRim': 1,
#                            'AssistedAtRim': 1,
#                            'ShortMidRangeBlockedDefReboundOpportunities': 1.0,
#                            'BlockedShortMidRange': 1,
#                            'BlockedShortMidRangeRecovered': 1,
#                            'ShortMidRangeBlockedDefRebounds': 1,
#                            'ShortMidRangeBlockedOffReboundOpportunities': 1.0,
#                            'ShortMidRangeBlocked': 1,
#                            'ShortMidRangeBlockedOffReboundedOpportunities': 1,
#                            'Personal Fouls': 2,
#                            'Period4Fouls3SecondsPlayedDef': 20.0,
#                            'Period4Fouls3SecondsPlayedOff': 13.0}),
#               '1626188-201939-202326-203110-2733': defaultdict(int,
#                           {'SecondsPlayedDef': 37.0,
#                            'Period4Fouls2SecondsPlayedDef': 37.0,
#                            'Arc3DefReboundOpportunities': 2.0,
#                            'DefPoss': 2.0,
#                            'Period4Fouls1SecondsPlayedDef': 65.0,
#                            'Period4Fouls4SecondsPlayedDef': 74.0,
#                            'Arc3DefRebounds': 1,
#                            'SecondsPlayedOff': 20.0,
#                            'Period4Fouls2SecondsPlayedOff': 20.0,
#                            'PlusMinus': 4.0,
#                            'OffPoss': 1.0,
#                            'Period4Fouls1SecondsPlayedOff': 40.0,
#                            'UnassistedArc3': 1,
#                            'Total3ptShotDistance': 26.1,
#                            'Total3ptShotsWithDistance': 1,
#                            'Period4Fouls4SecondsPlayedOff': 40.0,
#                            'PenaltySecondsPlayedDef': 9.0,
#                            'SecondChanceSecondsPlayedDef': 5.0,
#                            'PenaltyArc3DefReboundOpportunities': 1.0,
#                            'SecondChanceDefPoss': 1.0,
#                            'PenaltyDefPoss': 1.0,
#                            'Period4Fouls5SecondsPlayedDef': 9.0,
#                            'Technical Free Throws Trips': 1,
#                            'PenaltyTechnical Free Throws Trips': 1,
#                            'FtsMade': 1,
#                            'PenaltyFtsMade': 1}),
#               '1626172-201939-203110-2733-2738': defaultdict(int,
#                           {'SecondsPlayedDef': 108.0,
#                            'Period4Fouls1SecondsPlayedDef': 216.0,
#                            'PlusMinus': 0.0,
#                            'OpponentPoints': 12.0,
#                            'DefPoss': 10.0,
#                            'Period4Fouls4SecondsPlayedDef': 314.0,
#                            'SecondsPlayedOff': 198.0,
#                            'Period4Fouls1SecondsPlayedOff': 396.0,
#                            'Arc3OffReboundOpportunities': 3.0,
#                            'OffPoss': 11.0,
#                            'Period4Fouls4SecondsPlayedOff': 567.0,
#                            'MissedArc3': 3,
#                            'Total3ptShotDistance': 105.39999999999999,
#                            'Total3ptShotsWithDistance': 4,
#                            'Arc3OffReboundedOpportunities': 3,
#                            'Charge Fouls Drawn': 1,
#                            'ShortMidRangeOffReboundOpportunities': 2.0,
#                            'MissedShortMidRange': 2,
#                            'Total2ptShotDistance': 38.5,
#                            'Total2ptShotsWithDistance': 4,
#                            'ShortMidRangeOffReboundedOpportunities': 2,
#                            'ShortMidRangeDefRebounds': 1,
#                            'ShortMidRangeDefReboundOpportunities': 2.0,
#                            'AssistedArc3': 1,
#                            'Arc3Assists': 1,
#                            '201188:AssistsTo:1627832:Arc3': 1,
#                            'SecondChanceSecondsPlayedDef': 0.0,
#                            'SecondChanceDefPoss': 1.0,
#                            'LiveBallTurnovers': 2,
#                            'BadPassTurnovers': 2,
#                            'AssistedAtRim': 1,
#                            'AtRimAssists': 1,
#                            '200768:AssistsTo:1627783:AtRim': 1,
#                            'SecondChanceSecondsPlayedOff': 35.0,
#                            'OnFloorOffReb': 10,
#                            'SecondChanceOffPoss': 2.0,
#                            'Shooting Fouls Drawn': 2,
#                            '3pt Shooting Foul Free Throw Trips': 1,
#                            'SecondChance3pt Shooting Foul Free Throw Trips': 1,
#                            'FtsMade': 5,
#                            'SecondChanceFtsMade': 3,
#                            'ShortMidRangeOffRebounds': 1,
#                            'ShortMidRangeOffRebounded': 1,
#                            'Arc3DefRebounds': 1,
#                            'Arc3DefReboundOpportunities': 1.0,
#                            'Arc3OffRebounded': 1,
#                            'Arc3OffRebounds': 1,
#                            'SecondChanceMissedArc3': 1,
#                            'Steals': 1,
#                            '2pt Shooting Foul Free Throw Trips': 1,
#                            'PenaltySecondsPlayedOff': 18.0,
#                            'AssistedShortMidRange': 1,
#                            'PenaltyAssistedShortMidRange': 1,
#                            'PenaltyOffPoss': 2.0,
#                            'Period4Fouls5SecondsPlayedOff': 18.0,
#                            'ShortMidRangeAssists': 1,
#                            'PenaltyShortMidRangeAssists': 1,
#                            '200768:AssistsTo:1627783:ShortMidRange': 1,
#                            'Penalty200768:AssistsTo:1627783:ShortMidRange': 1,
#                            'PenaltySecondsPlayedDef': 10.0,
#                            'Personal Fouls': 1,
#                            'PenaltyPersonal Fouls': 1,
#                            'PenaltyDefPoss': 1.0,
#                            'Period4Fouls5SecondsPlayedDef': 10.0,
#                            'Period4Fouls2SecondsPlayedOff': 9.0,
#                            'DeadBallTurnovers': 1,
#                            'PenaltyDeadBallTurnovers': 1,
#                            'BadPassOutOfBoundsTurnovers': 1,
#                            'PenaltyBadPassOutOfBoundsTurnovers': 1}),
#               '1626172-1626188-201939-203110-2738': defaultdict(int,
#                           {'SecondsPlayedDef': 17.0,
#                            'Period4Fouls1SecondsPlayedDef': 34.0,
#                            'Arc3DefReboundOpportunities': 1.0,
#                            'DefPoss': 1.0,
#                            'Period4Fouls4SecondsPlayedDef': 49.0,
#                            'Arc3DefRebounds': 1,
#                            'SecondsPlayedOff': 14.0,
#                            'Period4Fouls1SecondsPlayedOff': 28.0,
#                            'PlusMinus': 3.0,
#                            'OffPoss': 1.0,
#                            'UnassistedArc3': 1,
#                            'Total3ptShotDistance': 25.8,
#                            'Total3ptShotsWithDistance': 1,
#                            'Period4Fouls4SecondsPlayedOff': 28.0,
#                            'Period4Fouls2SecondsPlayedOff': 14.0,
#                            'Period4Fouls2SecondsPlayedDef': 2.0}),
#               '201939-202326-203110-2733-2738': defaultdict(int,
#                           {'SecondsPlayedDef': 52.0,
#                            'Period4Fouls1SecondsPlayedDef': 104.0,
#                            'PenaltySecondsPlayedDef': 52.0,
#                            'FTDefRebounds': 1,
#                            'PenaltyFTDefRebounds': 1,
#                            'FTDefReboundOpportunities': 1.0,
#                            'PenaltyFTDefReboundOpportunities': 1.0,
#                            'DefPoss': 4.0,
#                            'SecondChanceDefPoss': 1.0,
#                            'PenaltyDefPoss': 4.0,
#                            'Period4Fouls4SecondsPlayedDef': 139.0,
#                            'SecondsPlayedOff': 80.0,
#                            'Period4Fouls1SecondsPlayedOff': 160.0,
#                            'MissedArc3': 2,
#                            'Total3ptShotDistance': 53.3,
#                            'Total3ptShotsWithDistance': 2,
#                            'SecondChanceSecondsPlayedOff': 65.0,
#                            'Arc3OffRebounds': 1,
#                            'Arc3OffReboundOpportunities': 2.0,
#                            'OnFloorOffReb': 5,
#                            'Arc3OffRebounded': 1,
#                            'Arc3OffReboundedOpportunities': 2,
#                            'PlusMinus': -3.0,
#                            'OffPoss': 3.0,
#                            'SecondChanceOffPoss': 1.0,
#                            'Period4Fouls4SecondsPlayedOff': 211.0,
#                            'UnassistedShortMidRange': 1,
#                            'Total2ptShotDistance': 13.3,
#                            'Total2ptShotsWithDistance': 1,
#                            'SecondChanceUnassistedShortMidRange': 1,
#                            'OpponentPoints': 6.0,
#                            'Shooting Fouls Drawn': 1,
#                            '2pt Shooting Foul Free Throw Trips': 1,
#                            'FtsMade': 1,
#                            'Personal Fouls': 1,
#                            'PenaltyPersonal Fouls': 1,
#                            'PenaltySecondsPlayedOff': 29.0,
#                            'PenaltyArc3OffReboundOpportunities': 1.0,
#                            'PenaltyOffPoss': 1.0,
#                            'Period4Fouls5SecondsPlayedOff': 29.0,
#                            'PenaltyMissedArc3': 1,
#                            'Period4Fouls5SecondsPlayedDef': 17.0})}),
#  '1610612761': defaultdict(<function pbpstats.game_data.GameData.get_aggregated_possession_stats_for_entity_type.<locals>.<lambda>()>,
#              {'1627783-200768-201188-201980-202695': defaultdict(int,
#                           {'SecondsPlayedDef': 228.0,
#                            'Period1Fouls0SecondsPlayedDef': 1085.0,
#                            'SecondChanceSecondsPlayedDef': 25.0,
#                            'ShortMidRangeBlockedDefReboundOpportunities': 2.0,
#                            'PlusMinus': -8.0,
#                            'OpponentPoints': 26.0,
#                            'DefPoss': 16.0,
#                            'SecondChanceDefPoss': 1.0,
#                            'BlockedShortMidRange': 2,
#                            'SecondsPlayedOff': 212.0,
#                            'Period1Fouls0SecondsPlayedOff': 885.0,
#                            'OffPoss': 16.0,
#                            'DeadBallTurnovers': 2,
#                            'BadPassOutOfBoundsTurnovers': 1,
#                            'Arc3OffReboundOpportunities': 2.0,
#                            'MissedArc3': 2,
#                            'Total3ptShotDistance': 101.8,
#                            'Total3ptShotsWithDistance': 4,
#                            'Arc3OffReboundedOpportunities': 2,
#                            'LiveBallTurnovers': 2,
#                            'BadPassTurnovers': 2,
#                            'Personal Fouls Drawn': 1,
#                            'Arc3DefReboundOpportunities': 2.0,
#                            'Arc3DefRebounds': 2,
#                            'AssistedAtRim': 2,
#                            'Total2ptShotDistance': 40.1,
#                            'Total2ptShotsWithDistance': 9,
#                            'AtRimAssists': 2,
#                            '203110:AssistsTo:1626172:AtRim': 2,
#                            'MissedShortMidRange': 2,
#                            'SecondChanceSecondsPlayedOff': 50.0,
#                            'ShortMidRangeOffRebounds': 1,
#                            'ShortMidRangeOffReboundOpportunities': 2.0,
#                            'OnFloorOffReb': 15,
#                            'ShortMidRangeOffRebounded': 1,
#                            'ShortMidRangeOffReboundedOpportunities': 2,
#                            'ShortMidRangeAssists': 2,
#                            'SecondChanceShortMidRangeAssists': 1,
#                            '1626172:AssistsTo:2738:ShortMidRange': 1,
#                            'SecondChance1626172:AssistsTo:2738:ShortMidRange': 1,
#                            'FTOffReboundOpportunities': 1.0,
#                            'SecondChanceOffPoss': 3.0,
#                            'Shooting Fouls Drawn': 3,
#                            'AssistedShortMidRange': 2,
#                            'SecondChanceAssistedShortMidRange': 1,
#                            '2pt And 1 Free Throw Trips': 1,
#                            'SecondChance2pt And 1 Free Throw Trips': 1,
#                            'FTOffReboundedOpportunities': 1,
#                            'Travels': 1,
#                            'ShortMidRangeBlockedDefRebounds': 1,
#                            'BlockedShortMidRangeRecovered': 1,
#                            '2pt Shooting Foul Free Throw Trips': 1,
#                            'FtsMade': 5,
#                            'Corner3OffReboundOpportunities': 1.0,
#                            'MissedCorner3': 1,
#                            'Corner3OffReboundedOpportunities': 1,
#                            '203110:AssistsTo:2738:ShortMidRange': 1,
#                            'ShortMidRangeDefRebounds': 2,
#                            'ShortMidRangeDefReboundOpportunities': 2.0,
#                            'AtRimOffReboundOpportunities': 2.0,
#                            'AtRimOffRebounds': 1,
#                            'Putbacks': 1,
#                            'UnassistedAtRim': 1,
#                            'SecondChanceUnassistedAtRim': 1,
#                            'MissedAtRim': 2,
#                            'AtRimOffRebounded': 1,
#                            'AtRimOffReboundedOpportunities': 2,
#                            'Personal Fouls': 1,
#                            'AssistedArc3': 1,
#                            'Arc3Assists': 1,
#                            '203110:AssistsTo:202691:Arc3': 1,
#                            'Shooting Fouls': 1,
#                            'Period2Fouls2SecondsPlayedDef': 33.0,
#                            'PenaltySecondsPlayedDef': 11.0,
#                            'PenaltyDefPoss': 2.0,
#                            'Period2Fouls0SecondsPlayedDef': 22.0,
#                            'Period2Fouls2SecondsPlayedOff': 105.0,
#                            'Period2Fouls0SecondsPlayedOff': 70.0,
#                            'Arc3OffRebounds': 1,
#                            'Arc3OffRebounded': 1,
#                            '3pt Shooting Foul Free Throw Trips': 1,
#                            'SecondChance3pt Shooting Foul Free Throw Trips': 1,
#                            'SecondChanceFtsMade': 3}),
#               '1627783-1627832-200768-201188-202695': defaultdict(int,
#                           {'SecondsPlayedDef': 507.0,
#                            'Period1Fouls0SecondsPlayedDef': 144.0,
#                            'FTDefRebounds': 1,
# ...
#                            'Period3Fouls3SecondsPlayedOff': 123.0,
#                            'Period3Fouls1SecondsPlayedOff': 99.0,
#                            'Personal Fouls Drawn': 1,
#                            'PenaltyPersonal Fouls Drawn': 1,
#                            'Penalty Free Throw Trips': 1,
#                            'PenaltyPenalty Free Throw Trips': 1,
#                            'FTOffReboundedOpportunities': 1,
#                            'Period3Fouls2SecondsPlayedDef': 119.0,
#                            'Period3Fouls3SecondsPlayedDef': 97.0,
#                            'Steals': 1,
#                            'PenaltySteals': 1,
#                            'Period3Fouls1SecondsPlayedDef': 74.0,
#                            '2pt Shooting Foul Free Throw Trips': 1,
#                            'Penalty2pt Shooting Foul Free Throw Trips': 1,
#                            'Personal Take Fouls': 1,
#                            'PenaltyPersonal Take Fouls': 1,
#                            'Corner3OffReboundOpportunities': 1.0,
#                            'PenaltyCorner3OffReboundOpportunities': 1.0,
#                            'MissedCorner3': 1,
#                            'PenaltyMissedCorner3': 1,
#                            'Corner3OffReboundedOpportunities': 1,
#                            'ShortMidRangeDefReboundOpportunities': 1.0,
#                            'PenaltyShortMidRangeDefReboundOpportunities': 1.0,
#                            'ShortMidRangeDefRebounds': 1,
#                            'PenaltyShortMidRangeDefRebounds': 1,
#                            'Personal Fouls': 1,
#                            'PenaltyPersonal Fouls': 1,
#                            'FTDefReboundOpportunities': 1.0,
#                            'PenaltyFTDefReboundOpportunities': 1.0,
#                            'FTDefRebounds': 1,
#                            'PenaltyFTDefRebounds': 1,
#                            'Arc3Assists': 1,
#                            'PenaltyArc3Assists': 1,
#                            '202326:AssistsTo:2738:Arc3': 1,
#                            'Penalty202326:AssistsTo:2738:Arc3': 1,
#                            'AssistedArc3': 1,
#                            'PenaltyAssistedArc3': 1}),
#               '1627783-1627832-201188-201980-202695': defaultdict(int,
#                           {'SecondsPlayedOff': 65.0,
#                            'Period3Fouls2SecondsPlayedOff': 195.0,
#                            'FTOffReboundOpportunities': 1.0,
#                            'OffPoss': 5.0,
#                            'Period3Fouls3SecondsPlayedOff': 65.0,
#                            'Period3Fouls1SecondsPlayedOff': 65.0,
#                            'FTOffReboundedOpportunities': 1,
#                            'SecondsPlayedDef': 73.0,
#                            'Period3Fouls2SecondsPlayedDef': 219.0,
#                            'PenaltySecondsPlayedDef': 73.0,
#                            'PlusMinus': 4.0,
#                            'OpponentPoints': 4.0,
#                            'DefPoss': 4.0,
#                            'PenaltyDefPoss': 4.0,
#                            'Period3Fouls3SecondsPlayedDef': 73.0,
#                            'Period3Fouls1SecondsPlayedDef': 73.0,
#                            'PenaltySecondsPlayedOff': 64.0,
#                            'PenaltyOffPoss': 4.0,
#                            'Corner3Assists': 1,
#                            'PenaltyCorner3Assists': 1,
#                            '201939:AssistsTo:2738:Corner3': 1,
#                            'Penalty201939:AssistsTo:2738:Corner3': 1,
#                            'AssistedCorner3': 1,
#                            'Total3ptShotDistance': 50.8,
#                            'Total3ptShotsWithDistance': 2,
#                            'PenaltyAssistedCorner3': 1,
#                            'LiveBallTurnovers': 1,
#                            'PenaltyLiveBallTurnovers': 1,
#                            'BadPassTurnovers': 1,
#                            'PenaltyBadPassTurnovers': 1,
#                            'Steals': 1,
#                            'PenaltySteals': 1,
#                            'AssistedArc3': 1,
#                            'PenaltyAssistedArc3': 1,
#                            'Arc3Assists': 1,
#                            'PenaltyArc3Assists': 1,
#                            '203110:AssistsTo:202691:Arc3': 1,
#                            'Penalty203110:AssistsTo:202691:Arc3': 1,
#                            'Arc3DefReboundOpportunities': 1.0,
#                            'PenaltyArc3DefReboundOpportunities': 1.0,
#                            'Arc3DefRebounds': 1,
#                            'PenaltyArc3DefRebounds': 1,
#                            'ShortMidRangeAssists': 1,
#                            'PenaltyShortMidRangeAssists': 1,
#                            '201939:AssistsTo:2738:ShortMidRange': 1,
#                            'Penalty201939:AssistsTo:2738:ShortMidRange': 1,
#                            'AssistedShortMidRange': 1,
#                            'Total2ptShotDistance': 4.3,
#                            'Total2ptShotsWithDistance': 1,
#                            'PenaltyAssistedShortMidRange': 1}),
#               '1627783-1627832-201586-201980-202695': defaultdict(int,
#                           {'SecondsPlayedDef': 72.0,
#                            'Period3Fouls2SecondsPlayedDef': 190.0,
#                            'PenaltySecondsPlayedDef': 72.0,
#                            'Arc3DefReboundOpportunities': 1.0,
#                            'PenaltyArc3DefReboundOpportunities': 1.0,
#                            'DefPoss': 3.0,
#                            'PenaltyDefPoss': 3.0,
#                            'Period3Fouls3SecondsPlayedDef': 98.0,
#                            'Period3Fouls0SecondsPlayedDef': 72.0,
#                            'Arc3DefRebounds': 1,
#                            'PenaltyArc3DefRebounds': 1,
#                            'SecondsPlayedOff': 31.0,
#                            'Period3Fouls2SecondsPlayedOff': 73.0,
#                            'PenaltySecondsPlayedOff': 31.0,
#                            'PlusMinus': 1.0,
#                            'OffPoss': 2.0,
#                            'PenaltyOffPoss': 2.0,
#                            'Period3Fouls3SecondsPlayedOff': 51.0,
#                            'UnassistedLongMidRange': 1,
#                            'Total2ptShotDistance': 17.9,
#                            'Total2ptShotsWithDistance': 1,
#                            'PenaltyUnassistedLongMidRange': 1,
#                            'Period3Fouls0SecondsPlayedOff': 31.0,
#                            'OpponentPoints': 4.0,
#                            'Shooting Fouls': 2,
#                            'PenaltyShooting Fouls': 2,
#                            'AssistedArc3': 1,
#                            'Total3ptShotDistance': 26.0,
#                            'Total3ptShotsWithDistance': 1,
#                            'PenaltyAssistedArc3': 1,
#                            'Arc3Assists': 1,
#                            'PenaltyArc3Assists': 1,
#                            '203110:AssistsTo:202691:Arc3': 1,
#                            'Penalty203110:AssistsTo:202691:Arc3': 1}),
#               '1626181-1627783-200768-201586-202695': defaultdict(int,
#                           {'SecondsPlayedOff': 28.0,
#                            'Period3Fouls2SecondsPlayedOff': 56.0,
#                            'PenaltySecondsPlayedOff': 28.0,
#                            'Arc3OffReboundOpportunities': 2.0,
#                            'PenaltyArc3OffReboundOpportunities': 2.0,
#                            'OffPoss': 2.0,
#                            'PenaltyOffPoss': 2.0,
#                            'Period3Fouls3SecondsPlayedOff': 56.0,
#                            'MissedArc3': 2,
#                            'Total3ptShotDistance': 52.6,
#                            'Total3ptShotsWithDistance': 2,
#                            'PenaltyMissedArc3': 2,
#                            'Arc3OffReboundedOpportunities': 2,
#                            'Period3Fouls1SecondsPlayedOff': 28.0,
#                            'SecondsPlayedDef': 10.0,
#                            'Period3Fouls2SecondsPlayedDef': 20.0,
#                            'PenaltySecondsPlayedDef': 10.0,
#                            'PlusMinus': -2.0,
#                            'OpponentPoints': 2.0,
#                            'DefPoss': 2.0,
#                            'PenaltyDefPoss': 2.0,
#                            'Period3Fouls3SecondsPlayedDef': 20.0,
#                            'Period3Fouls1SecondsPlayedDef': 10.0,
#                            'SecondChanceSecondsPlayedOff': 30.0,
#                            'OnFloorOffReb': 5,
#                            'PenaltyOnFloorOffReb': 5,
#                            'Arc3OffRebounded': 1,
#                            'SecondChanceOffPoss': 1.0,
#                            'Arc3OffRebounds': 1,
#                            'PenaltyArc3OffRebounds': 1,
#                            'LiveBallTurnovers': 1,
#                            'SecondChanceLiveBallTurnovers': 1,
#                            'PenaltyLiveBallTurnovers': 1,
#                            'BadPassTurnovers': 1,
#                            'SecondChanceBadPassTurnovers': 1,
#                            'PenaltyBadPassTurnovers': 1,
#                            'SecondChanceSecondsPlayedDef': 10.0,
#                            'Arc3DefReboundOpportunities': 1.0,
#                            'PenaltyArc3DefReboundOpportunities': 1.0,
#                            'ShortMidRangeDefReboundOpportunities': 1.0,
#                            'PenaltyShortMidRangeDefReboundOpportunities': 1.0,
#                            'SecondChanceDefPoss': 1.0}),
#               '1626181-1627783-1627832-200768-201188': defaultdict(int,
#                           {'SecondsPlayedOff': 48.0,
#                            'Period4Fouls2SecondsPlayedOff': 96.0,
#                            'AssistedShortMidRange': 1,
#                            'Total2ptShotDistance': 4.4,
#                            'Total2ptShotsWithDistance': 1,
#                            'PlusMinus': -1.0,
#                            'OffPoss': 2.0,
#                            'Period4Fouls0SecondsPlayedOff': 68.0,
#                            'Period4Fouls3SecondsPlayedOff': 76.0,
#                            'ShortMidRangeAssists': 1,
#                            '203110:AssistsTo:1626188:ShortMidRange': 1,
#                            'SecondsPlayedDef': 33.0,
#                            'Period4Fouls2SecondsPlayedDef': 66.0,
#                            'LongMidRangeDefReboundOpportunities': 1.0,
#                            'DefPoss': 2.0,
#                            'Period4Fouls0SecondsPlayedDef': 46.0,
#                            'Period4Fouls3SecondsPlayedDef': 53.0,
#                            'LongMidRangeDefRebounds': 1,
#                            'Personal Fouls Drawn': 1,
#                            'MissedArc3': 1,
#                            'Total3ptShotDistance': 26.4,
#                            'Total3ptShotsWithDistance': 1,
#                            'Arc3OffReboundOpportunities': 1.0,
#                            'Arc3OffReboundedOpportunities': 1,
#                            'OpponentPoints': 3.0}),
#               '1627783-1627832-200768-201586-202695': defaultdict(int,
#                           {'SecondsPlayedDef': 127.0,
#                            'Period4Fouls2SecondsPlayedDef': 263.0,
#                            'PlusMinus': -4.0,
#                            'OpponentPoints': 13.0,
#                            'DefPoss': 7.0,
#                            'Period4Fouls3SecondsPlayedDef': 156.0,
#                            'Period4Fouls4SecondsPlayedDef': 127.0,
#                            'SecondsPlayedOff': 104.0,
#                            'Period4Fouls2SecondsPlayedOff': 201.0,
#                            'Period4Fouls3SecondsPlayedOff': 144.0,
#                            'Period4Fouls4SecondsPlayedOff': 104.0,
#                            'PenaltySecondsPlayedOff': 94.0,
#                            'OffPoss': 7.0,
#                            'PenaltyOffPoss': 7.0,
#                            'Personal Fouls Drawn': 3,
#                            'DeadBallTurnovers': 2,
#                            'PenaltyDeadBallTurnovers': 2,
#                            'BadPassOutOfBoundsTurnovers': 1,
#                            'PenaltyBadPassOutOfBoundsTurnovers': 1,
#                            'SecondChanceSecondsPlayedDef': 85.0,
#                            'Arc3DefReboundOpportunities': 3.0,
#                            'SecondChanceDefPoss': 2.0,
#                            'SecondChanceSecondsPlayedOff': 15.0,
#                            'Arc3OffReboundOpportunities': 2.0,
#                            'PenaltyArc3OffReboundOpportunities': 2.0,
#                            'OnFloorOffReb': 10,
#                            'PenaltyOnFloorOffReb': 10,
#                            'Loose Ball Fouls Drawn': 1,
#                            'PenaltyLoose Ball Fouls Drawn': 1,
#                            'Penalty Free Throw Trips': 3,
#                            'SecondChancePenalty Free Throw Trips': 1,
#                            'PenaltyPenalty Free Throw Trips': 3,
#                            'FtsMade': 4,
#                            'SecondChanceFtsMade': 1,
#                            'PenaltyFtsMade': 4,
#                            'MissedArc3': 3,
#                            'Total3ptShotDistance': 141.7,
#                            'Total3ptShotsWithDistance': 4,
#                            'PenaltyMissedArc3': 3,
#                            'Arc3OffRebounded': 2,
#                            'Arc3OffReboundedOpportunities': 2,
#                            'Arc3OffRebounds': 2,
#                            'PenaltyArc3OffRebounds': 2,
#                            'FTOffReboundOpportunities': 1.0,
#                            'PenaltyFTOffReboundOpportunities': 1.0,
#                            'SecondChanceOffPoss': 2.0,
#                            'FTOffReboundedOpportunities': 1,
#                            'Period4Fouls1SecondsPlayedOff': 71.0,
#                            'Period4Fouls1SecondsPlayedDef': 89.0,
#                            'AssistedArc3': 1,
#                            'PenaltyAssistedArc3': 1,
#                            'Arc3Assists': 1,
#                            'PenaltyArc3Assists': 1,
#                            '2738:AssistsTo:203110:Arc3': 1,
#                            'Penalty2738:AssistsTo:203110:Arc3': 1,
#                            'Shooting Fouls': 1,
#                            'PenaltyPersonal Fouls Drawn': 2,
#                            'PenaltySecondsPlayedDef': 38.0,
#                            'PenaltyArc3DefReboundOpportunities': 1.0,
#                            'PenaltyDefPoss': 3.0,
#                            'Arc3DefRebounds': 1,
#                            'PenaltyArc3DefRebounds': 1,
#                            'AssistedAtRim': 1,
#                            'Total2ptShotDistance': 1.4,
#                            'Total2ptShotsWithDistance': 1,
#                            'PenaltyAssistedAtRim': 1,
#                            'AtRimAssists': 1,
#                            'PenaltyAtRimAssists': 1,
#                            '203110:AssistsTo:202326:AtRim': 1,
#                            'Penalty203110:AssistsTo:202326:AtRim': 1,
#                            'SecondChanceDeadBallTurnovers': 1,
#                            'Personal Fouls': 1,
#                            'PenaltyPersonal Fouls': 1,
#                            'HeaveMisses': 1}),
#               '1627783-1627832-200768-201980-202695': defaultdict(int,
#                           {'SecondsPlayedDef': 9.0,
#                            'Period4Fouls2SecondsPlayedDef': 18.0,
#                            'PenaltySecondsPlayedDef': 9.0,
#                            'DefPoss': 1.0,
#                            'PenaltyDefPoss': 1.0,
#                            'Period4Fouls3SecondsPlayedDef': 9.0,
#                            'Period4Fouls4SecondsPlayedDef': 9.0,
#                            'Period4Fouls1SecondsPlayedDef': 9.0})})}
